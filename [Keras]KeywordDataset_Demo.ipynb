# %%
# %%capture
import numpy as np
from pprint import pprint
import tensorflow as tf
import random

##import re
##import shutil
##import glob
##import os

# !pip install tensorflow-io
# !pip install audiomentations

# %%
# %%capture
# !wget https://storage.googleapis.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz
DATASET_DIR =  'dataset/'
# !mkdir dataset
# !tar -xf speech_commands_v0.02.tar.gz -C 'dataset'
# !rm -r -f speech_commands_v0.02.tar.gz

# !apt-get update && apt-get -qq install xxd

# !rm KeywordDataset.py
# !wget https://raw.githubusercontent.com/ben-karr/KeywordDetectionTinyML/master/KeywordDataset.py

# %%
from KeywordDataset import get_fns, KeywordDataset, get_meta, get_pretrain_words, get_model

# %% [markdown]
# # Prepare settings

# %% [markdown]
# At first we build a dictionary to hold metadata about training and data handling. At least pass the path to the dataset as `data_path` and `wanted_words` as a list. You can check the default values for the used keywords:

# %%
pprint(get_meta(data_path='dataset/', wanted_words = ['yes', 'no']))
# Out:
# {'audio': {'clip_duration': 1000,
#            'desired_samples': 16000,
#            'feature_bin_count': 40,
#            'fingerprint_size': 1960,
#            'sample_rate': 16000,
#            'spectrogram_lenght': 49,
#            'window_size_ms': 30,
#            'window_stride': 20},
#  'augmentation': {'background_frequency': 0.8,
#                   'background_volume_range': 0.1,
#                   'silence_percentage': 0.2,
#                   'time_shift_ms': 100.0,
#                   'unknown_percentage': 0.2},
#  'training': {'batch_size': 32,
#               'data_path': 'dataset/',
#               'epochs': 5,
#               'excluded_words': [],
#               'learning_rate': 0.001,
#               'wanted_words': ['yes', 'no']}}

# %% [markdown]
# If you want to use pretraining you can use `get_pretrain_words`. It pulls `n` words from the provided `path` ignoring the `excluded_words` so you can fine tune on these words while the pretrained model has not seen them yet.

# %%
data_path = 'dataset/'
excluded_words = ['yes', 'no']
wanted_words = get_pretrain_words(data_path, excluded_words, shuffle = True, n = 5)

meta_dict = get_meta(data_path=data_path, wanted_words=wanted_words, excluded_words=excluded_words, epochs=1)
pprint(meta_dict)
# Out:
# {'audio': {'clip_duration': 1000,
#            'desired_samples': 16000,
#            'feature_bin_count': 40,
#            'fingerprint_size': 1960,
#            'sample_rate': 16000,
#            'spectrogram_lenght': 49,
#            'window_size_ms': 30,
#            'window_stride': 20},
#  'augmentation': {'background_frequency': 0.8,
#                   'background_volume_range': 0.1,
#                   'silence_percentage': 0.2,
#                   'time_shift_ms': 100.0,
#                   'unknown_percentage': 0.2},
#  'training': {'batch_size': 32,
#               'data_path': 'dataset/',
#               'epochs': 1,
#               'excluded_words': ['yes', 'no'],
#               'learning_rate': 0.001,
#               'wanted_words': ['sheila', 'nine', 'five', 'down', 'follow']}}

# %% [markdown]
# # Load item / background filenames
# To load the .wav files into memory when training, the KeywordDataset needs a list of filenames to build batches from. `get_fns` collects all .wav files from subfolders in a given directory. Besides filenames cointained in folders named like one of the `wanted_words` it adds such words that are neither wanted nor excluded as `unknown` words as well as placeholders for silence (`silence_placeholder`) in the required ratio (given by `silent_pct`, `unknown_pct`). This ratio extends to train and validation split which size is determined by `val_pct`.
#
# _Note:_ When generating the list of filenames every audio file is loaded into memory to check if it has the required length and skipped if not. Since this takes some time you could save the results (as a python list or .csv); you could also do this if you want to fix the training / validation split for model comparison.

# %%
training_fns, validation_fns, background_fns = get_fns(
    path = meta_dict['training']['data_path'],
    wanted_words = meta_dict['training']['wanted_words'],
    excluded_words = meta_dict['training']['excluded_words'],
    desired_samples = meta_dict['audio']['desired_samples'],
    val_pct = 0.2,
    silent_pct = 0.2,
    unknown_pct = 0.2
)

# %%
print(training_fns[:10])
# Out:
# ['dataset/down/a6285644_nohash_1.wav', 'silence_placeholder', 'dataset/down/0819edb0_nohash_1.wav', 'dataset/four/f9643d42_nohash_3.wav', 'silence_placeholder', 'silence_placeholder', 'dataset/down/b36c27c2_nohash_0.wav', 'dataset/five/784e281a_nohash_1.wav', 'dataset/down/9b02d503_nohash_1.wav', 'dataset/down/8f4c551f_nohash_0.wav']

# %% [markdown]
# # Build training / validation datasets
# Other than the filenames, the class gets all required metadata from the provided `meta_dict`. For validation we use double the batch size of that in training since not using gradients in validation frees up memory.

# %%
training_ds = KeywordDataset(
    training_fns,
    background_fns,
    meta_dict,
    meta_dict['training']['batch_size'],
    is_validation = False
)
validation_ds = KeywordDataset(
    validation_fns,
    background_fns,
    meta_dict,
    meta_dict['training']['batch_size'] * 2,
    is_validation = True
)

# %% [markdown]
# The KeywordDataset class copies most of the data loading process from various parts of [input_data.py](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/speech_commands/input_data.py). A thing it adds is augmentations (in addition to the default backgound noise and shifting the audio signal a bit back or forth), in particular those of the [audiomentations library](https://github.com/iver56/audiomentations). By default it uses the following steps but I spend next to no time to find good performing augmentations / settings, so it would be a good idea to tinker around with them some more.

# %%
training_ds.augment.transforms
# Out:
# [<audiomentations.augmentations.clipping_distortion.ClippingDistortion at 0x7fdf0de55490>,
#  <audiomentations.augmentations.high_pass_filter.HighPassFilter at 0x7fdf0de55dd0>,
#  <audiomentations.augmentations.low_pass_filter.LowPassFilter at 0x7fdf0de55890>,
#  <audiomentations.augmentations.gain_transition.GainTransition at 0x7fdf0de55bd0>,
#  <audiomentations.augmentations.pitch_shift.PitchShift at 0x7fdf0de55510>,
#  <audiomentations.augmentations.seven_band_parametric_eq.SevenBandParametricEQ at 0x7fdf0de55c50>,
#  <audiomentations.augmentations.polarity_inversion.PolarityInversion at 0x7fdf0de55390>,
#  <audiomentations.augmentations.time_mask.TimeMask at 0x7fdf0de552d0>,
#  <audiomentations.augmentations.add_gaussian_noise.AddGaussianNoise at 0x7fdf0de55990>]

# %% [markdown]
# You can easily change this at the `training_ds.augment` argument, e.g.:
# ```python
# import audiomentations
# augs = audiomentations.Compose([
#   audiomentations.ClippingDistortion(p=0.5),
#   audiomentations.LowPassFilter(p=0.5),
#   …
# ])
# training_ds.augment = augs
# ```
# or remove augmentations (other than background and timeshift) at all:
# ```python
# training_ds.augment = lambda x: return x
# ```

# %% [markdown]
# If you want to have a quick listen at the results of your augmentations you can check the audio before the spectrogram is createt with the `get_audio` method.

# %%
from IPython.display import Audio

fn = training_ds.items[2]
label = training_ds.get_label(fn)
audio = training_ds.get_audio(fn, label).numpy().flatten()
audio = training_ds.augment(audio, sample_rate = meta_dict['audio']['sample_rate'])

print(f'Label: {label}')
Audio(audio, rate = 16000)
# Out:
# Label: down
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Building a model
# Since the data is ready to train now, we need to create a model. You can build your own keras model but make shure to use the Functional API since when using the Sequential API inference on the Arduino doesn't work (at least for me). Alternatively you can use `get_model` to receive an implementation of the `tiny` models from the original [tensorflow speech_command example](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/speech_commands/models.py) (`tiny_conv` or `tiny_embedding_conv`).

# %%
n_labels = len(training_ds.vocab)
model = get_model(n_labels, meta_dict, arch = 'tiny_conv', dropout = 0.5)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1960)]            0
#
#  reshape (Reshape)           (None, 1, 49, 40, 1)      0
#
#  conv2d (Conv2D)             (None, 1, 25, 20, 8)      648
#
#  dropout (Dropout)           (None, 1, 25, 20, 8)      0
#
#  flatten (Flatten)           (None, 4000)              0
#
#  dense (Dense)               (None, 7)                 28007
#
# =================================================================
# Total params: 28,655
# Trainable params: 28,655
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model
# Compile the model with the desired optimizer, loss and metrics and train for a few epochs.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate = meta_dict['training']['learning_rate']),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    metrics = ['accuracy']
)

# %%
history = model.fit(
    training_ds,
    validation_data = validation_ds,
    epochs = meta_dict['training']['epochs'],
    verbose = 1,
    shuffle = False, ## is handled by the dataloader
)
# Out:
# 565/565 [==============================] - 317s 560ms/step - loss: 1.5447 - accuracy: 0.4476 - val_loss: 1.0767 - val_accuracy: 0.5756

# %% [markdown]
# # Save model
# Use the save method of the keras model or `tf.keras.models.save_model` if you want to use `get_model` for transfer learning otherwise you have to change the head of the model yourself.

# %%
model.save('pretrain_1epochs')

# %% [markdown]
# # Prepare settings and dataset for transfer learning
# We can now use the words to fine tune for that we excluded before...

# %%
meta_dict = get_meta(data_path='dataset/', wanted_words = ['yes', 'no'])
pprint(meta_dict)
# Out:
# {'audio': {'clip_duration': 1000,
#            'desired_samples': 16000,
#            'feature_bin_count': 40,
#            'fingerprint_size': 1960,
#            'sample_rate': 16000,
#            'spectrogram_lenght': 49,
#            'window_size_ms': 30,
#            'window_stride': 20},
#  'augmentation': {'background_frequency': 0.8,
#                   'background_volume_range': 0.1,
#                   'silence_percentage': 0.2,
#                   'time_shift_ms': 100.0,
#                   'unknown_percentage': 0.2},
#  'training': {'batch_size': 32,
#               'data_path': 'dataset/',
#               'epochs': 5,
#               'excluded_words': [],
#               'learning_rate': 0.001,
#               'wanted_words': ['yes', 'no']}}

# %% [markdown]
# get the new filenames...

# %%
training_fns, validation_fns, background_fns = get_fns(
    path = meta_dict['training']['data_path'],
    wanted_words = meta_dict['training']['wanted_words'],
    excluded_words = meta_dict['training']['excluded_words'],
    desired_samples = meta_dict['audio']['desired_samples'],
    val_pct = 0.2,
    silent_pct = 0.2,
    unknown_pct = 0.2
)

# %% [markdown]
# and create the datasets:

# %%
training_ds = KeywordDataset(
    training_fns,
    background_fns,
    meta_dict,
    meta_dict['training']['batch_size'],
    is_validation = False
)
validation_ds = KeywordDataset(
    validation_fns,
    background_fns,
    meta_dict,
    meta_dict['training']['batch_size'] * 2,
    is_validation = True
)

# %% [markdown]
# # Load the pretrained model
# `get_model` loads the pretrained model from a given path, removes the head (last Dense layer) and adds a Dense layer that has the right amount of output nodes.

# %%
n_labels = len(training_ds.vocab)
fine_tune_model = get_model(n_labels, meta_dict, pretrain_path = 'pretrain_1epochs')
fine_tune_model.summary()

# %%
fine_tune_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate = meta_dict['training']['learning_rate']),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    metrics = ['accuracy']
)

# %% [markdown]
# As you can see in the summary: `get_model` freezes all but the last layer (`Non-trainable params: 648`). We should train the model in this fashion for a few epochs so the untrained layer can 'catch up' with the pretrained ones.

# %%
fine_tune_history = fine_tune_model.fit(
    training_ds,
    validation_data = validation_ds,
    epochs = 2,
    verbose = 1,
    shuffle = False, ## is handled by dataloader
)
# Out:
# Epoch 1/2
# 333/333 [==============================] - 181s 544ms/step - loss: 1.0259 - accuracy: 0.5752 - val_loss: 0.4412 - val_accuracy: 0.8725
# Epoch 2/2
# 333/333 [==============================] - 178s 534ms/step - loss: 0.9001 - accuracy: 0.6418 - val_loss: 0.3859 - val_accuracy: 0.8903

# %% [markdown]
# Unfreeze the model and train some more.

# %%
fine_tune_model.trainable = True
fine_tune_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1960)]            0
#
#  reshape (Reshape)           (None, 1, 49, 40, 1)      0
#
#  conv2d (Conv2D)             (None, 1, 25, 20, 8)      648
#
#  dropout (Dropout)           (None, 1, 25, 20, 8)      0
#
#  flatten (Flatten)           (None, 4000)              0
#
#  dense_1 (Dense)             (None, 4)                 16004
#
# =================================================================
# Total params: 16,652
# Trainable params: 16,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
fine_tune_history_thawn = fine_tune_model.fit(
    training_ds,
    validation_data = validation_ds,
    epochs = 3,
    verbose = 1,
    shuffle = False, ## is handled by dataloader
)
# Out:
# Epoch 1/3
# 333/333 [==============================] - 179s 538ms/step - loss: 0.8751 - accuracy: 0.6544 - val_loss: 0.3589 - val_accuracy: 0.8948
# Epoch 2/3
# 333/333 [==============================] - 183s 548ms/step - loss: 0.8814 - accuracy: 0.6559 - val_loss: 0.3610 - val_accuracy: 0.8915
# Epoch 3/3
# 333/333 [==============================] - 192s 576ms/step - loss: 0.8733 - accuracy: 0.6584 - val_loss: 0.3578 - val_accuracy: 0.8931

# %% [markdown]
# # Save model for TFLite
# from: [CustomDatasetKWSModel](https://colab.research.google.com/github/tinyMLx/colabs/blob/master/4-6-8-CustomDatasetKWSModel.ipynb) of [Deploying TinyML](https://learning.edx.org/course/course-v1:HarvardX+TinyML3+1T2022/home).

# %%
export_name = 'model_fromPre_wAugs'
export_dir = f'saved_model/{export_name}'
tf.saved_model.save(fine_tune_model, export_dir)

# %% [markdown]
# Build a dataset generator for quantization

# %%
REP_DATA_SIZE = 100
items = validation_ds.items
random.shuffle(items)
def representative_dataset_gen():
    for fn in items[:REP_DATA_SIZE]:
            label = validation_ds.get_label(fn)
            audio = validation_ds.get_audio(fn, label)
            spectro = validation_ds.get_spectrogram(audio).reshape(1,meta_dict['audio']['fingerprint_size'])
            
            yield [spectro]

# %% [markdown]
# Do quantization:

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)

converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.inference_input_type = tf.int8 #tf.compat.v1.lite.constants.INT8 
converter.inference_output_type = tf.int8 #tf.compat.v1.lite.constants.INT8

converter.representative_dataset = representative_dataset_gen
tflite_model = converter.convert()
tflite_model_size = open(f"{export_name}.tflite", "wb").write(tflite_model)
print(f"Quantized modelsize: {tflite_model_size}")
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# Quantized modelsize: 19424

# %% [markdown]
# # Save for Arduino

# %%
# !xxd -i {export_name}.tflite > {export_name}.cc
# !cat {export_name}.cc
# Out:
# unsigned char model_fromPre_wAugs_tflite[] = {
#   0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x14, 0x00, 0x20, 0x00,
#   0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x1c, 0x00, 0x14, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00, 0x34, 0x01, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0xdc, 0x00, 0x00, 0x00, 0x5c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xf8, 0x05, 0x00, 0x00, 0x34, 0x04, 0x00, 0x00,
#   0xa8, 0x02, 0x00, 0x00, 0xe8, 0x01, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x30, 0x01, 0x00, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x80, 0x4b, 0x00, 0x00,
#   0x7c, 0x4b, 0x00, 0x00, 0x68, 0x4a, 0x00, 0x00, 0x04, 0x4a, 0x00, 0x00,
#   0xac, 0x46, 0x00, 0x00, 0xd8, 0x45, 0x00, 0x00, 0xe8, 0x06, 0x00, 0x00,
#   0x70, 0x06, 0x00, 0x00, 0x60, 0x4b, 0x00, 0x00, 0x5c, 0x4b, 0x00, 0x00,
#   0x58, 0x4b, 0x00, 0x00, 0x54, 0x4b, 0x00, 0x00, 0x50, 0x4b, 0x00, 0x00,
#   0xb4, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0a, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x0f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76,
#   0x69, 0x6e, 0x67, 0x5f, 0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x24, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x07, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x00,
#   0x36, 0xb6, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
#   0x69, 0x6e, 0x70, 0x75, 0x74, 0x5f, 0x31, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00,
#   0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74,
#   0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00,
#   0x7e, 0xb6, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x31, 0x2e, 0x31, 0x34, 0x2e, 0x30, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x0f, 0x00, 0x00, 0x00, 0x4d, 0x4c, 0x49, 0x52,
#   0x20, 0x43, 0x6f, 0x6e, 0x76, 0x65, 0x72, 0x74, 0x65, 0x64, 0x2e, 0x00,
#   0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0c, 0x00,
#   0x10, 0x00, 0x14, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x44, 0x00, 0x00, 0x00, 0x48, 0x00, 0x00, 0x00, 0x4c, 0x00, 0x00, 0x00,
#   0x60, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0xb8, 0x49, 0x00, 0x00,
#   0x54, 0x49, 0x00, 0x00, 0xd8, 0x48, 0x00, 0x00, 0xf8, 0x47, 0x00, 0x00,
#   0xc4, 0x44, 0x00, 0x00, 0x34, 0x44, 0x00, 0x00, 0x4c, 0x05, 0x00, 0x00,
#   0x8c, 0x04, 0x00, 0x00, 0xc8, 0x02, 0x00, 0x00, 0xe4, 0x01, 0x00, 0x00,
#   0x38, 0x01, 0x00, 0x00, 0x78, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x28, 0x04, 0x00, 0x00, 0x44, 0x02, 0x00, 0x00,
#   0x9c, 0x01, 0x00, 0x00, 0xcc, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x6d, 0x61, 0x69, 0x6e, 0x00, 0x00, 0x00, 0x00,
#   0xe6, 0xfd, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x03, 0x00, 0x00, 0x00,
#   0x1c, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x56, 0xb7, 0xff, 0xff, 0x00, 0x00, 0x80, 0x3f, 0x01, 0x00, 0x00, 0x00,
#   0x0b, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x00, 0x00,
#   0x08, 0xfc, 0xff, 0xff, 0x19, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x19,
#   0x02, 0x00, 0x00, 0x00, 0x00, 0xb7, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x14, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x19, 0x00, 0x00, 0x00,
#   0x53, 0x74, 0x61, 0x74, 0x65, 0x66, 0x75, 0x6c, 0x50, 0x61, 0x72, 0x74,
#   0x69, 0x74, 0x69, 0x6f, 0x6e, 0x65, 0x64, 0x43, 0x61, 0x6c, 0x6c, 0x3a,
#   0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0xec, 0xb6, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x80, 0x3b,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x9e, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x08,
#   0x02, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xfc, 0xb6, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0xc4, 0xfc, 0xff, 0xff,
#   0x09, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x04, 0x00, 0x00, 0x00,
#   0xbc, 0xb7, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x14, 0x00, 0x00, 0x00,
#   0x0b, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x54, 0x00, 0x00, 0x00,
#   0x44, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x2e, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f,
#   0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c,
#   0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f, 0x42,
#   0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0xbc, 0xb7, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x6d, 0x38, 0x81, 0x3d, 0x01, 0x00, 0x00, 0x00, 0x49, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x86, 0xfd, 0xff, 0xff, 0x10, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x64, 0xb8, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x14, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xa0, 0x0f, 0x00, 0x00, 0x17, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x5f, 0x31, 0x2f, 0x66, 0x6c, 0x61, 0x74, 0x74, 0x65, 0x6e, 0x2f,
#   0x52, 0x65, 0x73, 0x68, 0x61, 0x70, 0x65, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0xa0, 0x0f, 0x00, 0x00, 0x4c, 0xb8, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x40, 0xeb, 0x1d, 0x3d, 0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff,
#   0xff, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00,
#   0x18, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x07, 0x00, 0x14, 0x00,
#   0x0e, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x01, 0x00, 0x00, 0x00,
#   0x30, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0f, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x01, 0x01, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x4c, 0xfe, 0xff, 0xff, 0x03, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x03, 0x03, 0x00, 0x00, 0x00, 0x44, 0xb9, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x09, 0x14, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x44, 0x01, 0x00, 0x00, 0x2c, 0x01, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x19, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x0c, 0x01, 0x00, 0x00,
#   0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f, 0x63, 0x6f, 0x6e, 0x76,
#   0x32, 0x64, 0x2f, 0x52, 0x65, 0x6c, 0x75, 0x3b, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x5f, 0x31, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x73,
#   0x71, 0x75, 0x65, 0x65, 0x7a, 0x65, 0x5f, 0x62, 0x61, 0x74, 0x63, 0x68,
#   0x5f, 0x64, 0x69, 0x6d, 0x73, 0x2f, 0x52, 0x65, 0x73, 0x68, 0x61, 0x70,
#   0x65, 0x5f, 0x31, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x73, 0x71, 0x75, 0x65, 0x65,
#   0x7a, 0x65, 0x5f, 0x62, 0x61, 0x74, 0x63, 0x68, 0x5f, 0x64, 0x69, 0x6d,
#   0x73, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x3b, 0x6d, 0x6f,
#   0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64,
#   0x2f, 0x73, 0x71, 0x75, 0x65, 0x65, 0x7a, 0x65, 0x5f, 0x62, 0x61, 0x74,
#   0x63, 0x68, 0x5f, 0x64, 0x69, 0x6d, 0x73, 0x2f, 0x52, 0x65, 0x73, 0x68,
#   0x61, 0x70, 0x65, 0x2f, 0x73, 0x68, 0x61, 0x70, 0x65, 0x3b, 0x6d, 0x6f,
#   0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f, 0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64,
#   0x2f, 0x73, 0x71, 0x75, 0x65, 0x65, 0x7a, 0x65, 0x5f, 0x62, 0x61, 0x74,
#   0x63, 0x68, 0x5f, 0x64, 0x69, 0x6d, 0x73, 0x2f, 0x52, 0x65, 0x73, 0x68,
#   0x61, 0x70, 0x65, 0x3b, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32,
#   0x44, 0x2f, 0x52, 0x65, 0x73, 0x68, 0x61, 0x70, 0x65, 0x5f, 0x31, 0x3b,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x3b,
#   0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f, 0x63, 0x6f, 0x6e, 0x76,
#   0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44, 0x2f, 0x43, 0x6f,
#   0x6e, 0x76, 0x32, 0x44, 0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0x19, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x34, 0xba, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x40, 0xeb, 0x1d, 0x3d,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x0a, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x08, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x10, 0x00,
#   0x0b, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x16, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x16, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0xbb, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x14, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x6c, 0x00, 0x00, 0x00,
#   0x54, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x31, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x35, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32,
#   0x44, 0x2f, 0x52, 0x65, 0x73, 0x68, 0x61, 0x70, 0x65, 0x3b, 0x6d, 0x6f,
#   0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f, 0x72, 0x65, 0x73, 0x68, 0x61, 0x70,
#   0x65, 0x2f, 0x52, 0x65, 0x73, 0x68, 0x61, 0x70, 0x65, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x31, 0x00, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x1c, 0xbb, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x50, 0x50, 0xd0, 0x3d, 0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff,
#   0xff, 0xff, 0xff, 0xff, 0x22, 0xbc, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x4d, 0x06, 0x00, 0x00, 0xf4, 0xf6, 0xff, 0xff,
#   0xad, 0x04, 0x00, 0x00, 0x40, 0xff, 0xff, 0xff, 0x1a, 0xbc, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x02, 0x10, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73,
#   0x65, 0x5f, 0x31, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00,
#   0x8c, 0xbb, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x62, 0x87, 0xbe, 0x38, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x96, 0xbc, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x80, 0x3e, 0x00, 0x00,
#   0x05, 0x08, 0xf5, 0xd8, 0xf9, 0x12, 0x0d, 0xfc, 0x0a, 0xfc, 0x2a, 0xf2,
#   0xf1, 0x1f, 0xf7, 0xf7, 0xf9, 0xee, 0x06, 0xfa, 0x07, 0x14, 0xf7, 0x07,
#   0x0e, 0xf4, 0x04, 0xdb, 0xe6, 0x24, 0xe6, 0xfa, 0x04, 0xf9, 0xf6, 0xc6,
#   0xd0, 0x07, 0x0e, 0x02, 0x26, 0x0b, 0xee, 0xeb, 0x08, 0xf3, 0xf8, 0xe4,
#   0xf8, 0x0b, 0x03, 0xfa, 0xf8, 0xf3, 0xe7, 0xf8, 0xff, 0x0c, 0xed, 0xef,
#   0xf1, 0xee, 0xf6, 0x01, 0xf4, 0xfa, 0xda, 0xe4, 0x0c, 0x08, 0xe4, 0xeb,
#   0x00, 0xec, 0xec, 0x05, 0xf2, 0xf9, 0xeb, 0xe6, 0x0c, 0x09, 0x0d, 0xf7,
#   0xef, 0x0a, 0xf2, 0xf4, 0x01, 0x01, 0xf0, 0xf6, 0xef, 0xd8, 0x07, 0xfa,
#   0xfc, 0x04, 0xf8, 0x05, 0xec, 0x0b, 0xf8, 0xf0, 0xe6, 0x09, 0xfc, 0xfc,
#   0xf0, 0x03, 0xf6, 0xfb, 0x01, 0x0e, 0xec, 0xe4, 0xf1, 0x05, 0x00, 0x08,
#   0x0c, 0xfc, 0xe9, 0xf3, 0xf7, 0x0e, 0xfc, 0x02, 0xce, 0xf8, 0xf5, 0x04,
#   0xef, 0x12, 0xf1, 0xfe, 0xf8, 0x0e, 0x0d, 0xde, 0xf3, 0xf1, 0xfb, 0xee,
#   0xf9, 0xec, 0x20, 0xf4, 0xdf, 0xfe, 0xf0, 0x09, 0xfe, 0xdc, 0x1a, 0xf7,
#   0xfd, 0xef, 0x00, 0x07, 0x04, 0x0e, 0x12, 0xf0, 0x04, 0x20, 0x16, 0x0e,
#   0x08, 0xe9, 0x0e, 0xfd, 0xf9, 0x0d, 0x1a, 0xfa, 0x00, 0xf5, 0x10, 0xec,
#   0x0c, 0x0c, 0x0c, 0x00, 0x18, 0xf1, 0xef, 0xfc, 0x19, 0x14, 0x0b, 0xff,
#   0x15, 0x0c, 0xef, 0xea, 0xf7, 0xf7, 0x00, 0x20, 0x0d, 0xed, 0xfd, 0xfa,
#   0x02, 0xf1, 0xed, 0xf2, 0x17, 0xe8, 0xf3, 0xde, 0xd8, 0x04, 0xf1, 0xf8,
#   0xf7, 0xe8, 0xf9, 0xdf, 0x0a, 0x06, 0xec, 0xe6, 0xe1, 0xf7, 0xff, 0xf1,
#   0x02, 0xee, 0xff, 0xe9, 0xfb, 0xdb, 0xec, 0xcf, 0x13, 0x0c, 0x06, 0xf0,
#   0x04, 0xe5, 0xe8, 0xfb, 0xdf, 0xf8, 0xfc, 0x1c, 0xd2, 0xf4, 0xf1, 0xd1,
#   0x0a, 0x07, 0xf1, 0xf2, 0x15, 0x04, 0x08, 0xd4, 0xfd, 0x20, 0xe5, 0xfe,
#   0xfb, 0xec, 0x08, 0x02, 0xf7, 0x18, 0x18, 0xed, 0xfb, 0x06, 0x0a, 0xf1,
#   0x15, 0xfc, 0x19, 0xde, 0xe8, 0xda, 0xf6, 0xf6, 0xee, 0x19, 0xe2, 0x00,
#   0xe0, 0xcc, 0xf8, 0x09, 0xff, 0xe3, 0xfb, 0xf7, 0xd3, 0xf7, 0xfd, 0xf5,
#   0xfc, 0x0e, 0xf1, 0xe1, 0xf2, 0xf1, 0xf7, 0xf5, 0x0b, 0x01, 0xed, 0xef,
#   0xf5, 0xe5, 0xd8, 0xe4, 0x02, 0xde, 0xfd, 0x20, 0x04, 0xf3, 0x0d, 0xff,
#   0x03, 0x46, 0x14, 0x0b, 0x01, 0x07, 0x08, 0x0f, 0xfe, 0xf0, 0x0e, 0xfb,
#   0x0d, 0x15, 0x08, 0xff, 0x10, 0x13, 0xf6, 0x13, 0x00, 0xee, 0xe8, 0xf3,
#   0xf7, 0xfc, 0x14, 0xf7, 0x1c, 0xfd, 0x04, 0xe5, 0xff, 0x04, 0x09, 0x02,
#   0x13, 0xf1, 0xf2, 0xef, 0xdd, 0x03, 0xf3, 0xee, 0x05, 0xf5, 0x0e, 0xe1,
#   0xe4, 0xea, 0xe7, 0x18, 0x13, 0xe5, 0xf4, 0xf8, 0x03, 0xf2, 0xed, 0xf9,
#   0xd2, 0x06, 0x04, 0x12, 0xf7, 0xfa, 0x18, 0xf0, 0x18, 0xf8, 0x01, 0x00,
#   0xe1, 0xe7, 0xf6, 0xd9, 0x0a, 0xe8, 0x12, 0xf4, 0x06, 0xff, 0x01, 0xf3,
#   0xc4, 0xff, 0x18, 0xd5, 0xf5, 0xf5, 0xec, 0xda, 0xfa, 0x07, 0x1c, 0xfc,
#   0x1a, 0x01, 0xee, 0x02, 0xf0, 0xf7, 0xe9, 0xf4, 0x14, 0xf1, 0x1c, 0x0c,
#   0x0f, 0xfd, 0xfd, 0x02, 0x09, 0x06, 0xe6, 0x14, 0xf9, 0xe0, 0xe9, 0x0d,
#   0x1a, 0xe6, 0x04, 0x1c, 0xee, 0xed, 0x00, 0x16, 0x03, 0x11, 0x0f, 0xe5,
#   0xd1, 0x01, 0x07, 0x05, 0xf9, 0xf4, 0x01, 0xfd, 0x2b, 0xea, 0x02, 0xe4,
#   0xf3, 0x01, 0x00, 0xe3, 0x14, 0x0f, 0xe8, 0xea, 0xfb, 0x06, 0xe5, 0x1e,
#   0x0a, 0xf9, 0x1a, 0xfc, 0xfc, 0x1a, 0x05, 0x1c, 0xfd, 0x04, 0xfd, 0xe5,
#   0x14, 0x08, 0x02, 0x0e, 0x16, 0xfa, 0x16, 0xe9, 0xe9, 0x0e, 0xfb, 0xfc,
#   0x1c, 0x0d, 0x06, 0x0f, 0xea, 0x04, 0x05, 0x19, 0xed, 0x25, 0xe3, 0xd2,
#   0xe9, 0x08, 0x18, 0x13, 0x0b, 0x21, 0x14, 0xf2, 0x12, 0xfc, 0x28, 0xf7,
#   0x13, 0xfb, 0x07, 0xe5, 0xf4, 0xed, 0x26, 0xec, 0x21, 0xf6, 0xfa, 0x08,
#   0x1c, 0xdf, 0xef, 0xea, 0x0a, 0x11, 0xf1, 0xe8, 0x1d, 0xfe, 0xfa, 0x00,
#   0x07, 0xf6, 0x00, 0xe4, 0x03, 0xfe, 0x0a, 0xe5, 0xff, 0x13, 0xf4, 0xff,
#   0xff, 0x09, 0x02, 0x19, 0x1d, 0xfa, 0xf7, 0x01, 0x22, 0xfb, 0x04, 0xfe,
#   0x11, 0xf1, 0x14, 0xf5, 0x03, 0x08, 0xff, 0x0c, 0x0f, 0x01, 0x13, 0x05,
#   0xb2, 0xf8, 0x11, 0xe8, 0xf6, 0x16, 0xf5, 0xf1, 0x04, 0xee, 0x2a, 0xf6,
#   0xf0, 0xd9, 0x11, 0x04, 0xf4, 0xee, 0x02, 0xea, 0x00, 0x1f, 0xf8, 0xeb,
#   0x10, 0x00, 0x02, 0xfc, 0xff, 0xf3, 0x07, 0xce, 0x08, 0x00, 0xf7, 0x06,
#   0xf7, 0xf5, 0x15, 0xf3, 0xf7, 0x00, 0xdb, 0xf3, 0xe8, 0xec, 0xe3, 0x01,
#   0xfd, 0x0f, 0x0b, 0xe7, 0x09, 0xfa, 0xfb, 0x1a, 0xe3, 0x3b, 0x07, 0xef,
#   0x08, 0x05, 0x0e, 0xf2, 0xd5, 0xfd, 0x15, 0xf6, 0x04, 0xf2, 0xf4, 0x03,
#   0xcf, 0x09, 0xf9, 0xef, 0x01, 0x00, 0xfd, 0xe0, 0xd1, 0xfe, 0xff, 0x0e,
#   0x21, 0x15, 0x06, 0x08, 0x01, 0x06, 0xf7, 0x18, 0x08, 0xf4, 0xec, 0x0e,
#   0x04, 0x04, 0xee, 0x03, 0x04, 0xfd, 0x17, 0xfe, 0x0b, 0x07, 0x0d, 0x00,
#   0x09, 0x06, 0xe2, 0xee, 0xe1, 0xf3, 0xff, 0x00, 0x07, 0x05, 0x03, 0x07,
#   0x02, 0xf7, 0xf8, 0x18, 0x0b, 0xfe, 0x1f, 0x03, 0x12, 0x04, 0xf5, 0x06,
#   0xfe, 0x08, 0x21, 0x2e, 0xfb, 0xdd, 0xf7, 0x05, 0x0a, 0x11, 0x14, 0x0c,
#   0x0a, 0x02, 0x14, 0xf5, 0x03, 0x1d, 0xe4, 0xe5, 0x15, 0xfb, 0x19, 0xee,
#   0x0b, 0xe9, 0x0f, 0xf7, 0xf1, 0x11, 0x07, 0x15, 0xff, 0xf7, 0x11, 0xf4,
#   0xfb, 0x10, 0x00, 0xdf, 0xe8, 0xef, 0xf7, 0x04, 0x02, 0x0e, 0x01, 0xe2,
#   0xec, 0xfe, 0x18, 0xf7, 0x00, 0x03, 0x0e, 0x01, 0x0d, 0xf2, 0x06, 0x02,
#   0x12, 0x0e, 0x0b, 0xed, 0xee, 0x0a, 0x17, 0xfa, 0xf8, 0x0a, 0x00, 0xdd,
#   0x01, 0x0f, 0x07, 0x01, 0xf0, 0x08, 0xfc, 0xf8, 0x04, 0x0a, 0x0b, 0x0b,
#   0xe8, 0xfe, 0x25, 0x03, 0x08, 0xe1, 0x15, 0xee, 0x0e, 0xe9, 0xff, 0x15,
#   0x18, 0xdb, 0x0b, 0xe5, 0x04, 0xff, 0x1e, 0xf2, 0x12, 0xf2, 0xe8, 0xfc,
#   0xf2, 0xfe, 0x11, 0xee, 0x1f, 0xf0, 0xf8, 0x0c, 0x0f, 0x06, 0x03, 0x18,
#   0x21, 0xfe, 0x10, 0xf4, 0x17, 0xe6, 0xe8, 0x09, 0x20, 0x06, 0x02, 0x13,
#   0x0c, 0xfa, 0x22, 0xf9, 0xf1, 0x00, 0x0d, 0xe4, 0xe1, 0x01, 0xff, 0xed,
#   0x0e, 0xe7, 0x1c, 0xd9, 0xe2, 0x0b, 0x00, 0x03, 0xee, 0xe8, 0x0a, 0xee,
#   0x13, 0xf6, 0xfc, 0xf8, 0x18, 0xf8, 0x03, 0xf2, 0x0e, 0x07, 0xdd, 0xed,
#   0xef, 0x06, 0x11, 0xf3, 0xcd, 0xe8, 0x1d, 0x0e, 0x0e, 0xf7, 0x0d, 0xfd,
#   0x04, 0xfa, 0xfa, 0x0e, 0xe7, 0xed, 0x0d, 0xed, 0x09, 0x07, 0x0a, 0x09,
#   0x03, 0x10, 0x00, 0xf5, 0x11, 0x0f, 0x15, 0xff, 0xfb, 0x09, 0xff, 0x0c,
#   0x04, 0x0a, 0x09, 0xfb, 0xe9, 0x0b, 0x11, 0xe1, 0xf0, 0x03, 0xf3, 0xe7,
#   0xf7, 0x13, 0xf9, 0x0b, 0x10, 0xf9, 0x15, 0x03, 0x01, 0x0c, 0x09, 0xf6,
#   0x0f, 0x0a, 0x23, 0xf5, 0xe3, 0x0c, 0xfd, 0xf4, 0xff, 0xfb, 0xf6, 0xf0,
#   0x03, 0xf6, 0xea, 0xeb, 0x0b, 0x23, 0x16, 0xf3, 0xfc, 0xf5, 0xfb, 0xed,
#   0x03, 0xe7, 0x02, 0x1e, 0xf2, 0x1a, 0x05, 0xdf, 0xcd, 0x00, 0xfa, 0x1c,
#   0x1c, 0x10, 0x08, 0x0d, 0xfc, 0xfc, 0x11, 0x16, 0x08, 0x1c, 0xd8, 0x08,
#   0x07, 0x03, 0x05, 0x19, 0x1b, 0x12, 0xdf, 0xf0, 0x00, 0xe2, 0x01, 0x17,
#   0xf0, 0xde, 0xff, 0x01, 0xe4, 0xf9, 0xfb, 0x0b, 0xff, 0x05, 0x02, 0xec,
#   0xde, 0xe5, 0x00, 0x07, 0x16, 0xfb, 0xee, 0xf0, 0x01, 0xf7, 0x0b, 0xff,
#   0x11, 0xf3, 0x14, 0xe9, 0xe9, 0xea, 0xfd, 0xfd, 0xff, 0x02, 0xf8, 0xdf,
#   0xdd, 0xfd, 0xf5, 0xe8, 0x0a, 0xfc, 0x0c, 0xff, 0xd4, 0xf3, 0x07, 0xf2,
#   0x05, 0x08, 0xec, 0xf4, 0xe1, 0x01, 0xed, 0x0e, 0xff, 0x03, 0xdb, 0x0d,
#   0x0d, 0xfc, 0x15, 0xf1, 0xf3, 0xf5, 0x0b, 0x03, 0x10, 0xe8, 0xec, 0x18,
#   0xfd, 0xfe, 0xf9, 0xf6, 0x0c, 0x0a, 0x03, 0xed, 0xdb, 0x1b, 0xf7, 0xf9,
#   0xed, 0x0c, 0x15, 0xee, 0xe3, 0x10, 0x18, 0xf5, 0x04, 0xfc, 0x10, 0x08,
#   0xff, 0x18, 0xf7, 0x13, 0xfb, 0xf5, 0x1c, 0xec, 0x04, 0xfb, 0xfe, 0xef,
#   0xf2, 0x09, 0x02, 0xfa, 0x02, 0xf1, 0xfd, 0xde, 0xf9, 0xfb, 0x10, 0x0b,
#   0x03, 0xe4, 0x06, 0xeb, 0xff, 0xf8, 0x03, 0x04, 0x1e, 0xf8, 0x0e, 0xe3,
#   0xd1, 0xf6, 0x14, 0x07, 0x12, 0xff, 0xd2, 0x0e, 0xe1, 0xde, 0x03, 0xf6,
#   0x22, 0xf3, 0xff, 0x06, 0xeb, 0x01, 0x14, 0xe7, 0x04, 0x03, 0xf4, 0x0a,
#   0xfe, 0xfe, 0xe4, 0xf9, 0xf8, 0x04, 0xd3, 0xe2, 0xed, 0xd8, 0x07, 0xee,
#   0x05, 0xdc, 0xf7, 0xed, 0xfa, 0xc4, 0xf2, 0xf3, 0xf4, 0xfb, 0x13, 0xfc,
#   0xd9, 0xea, 0x11, 0x01, 0xf7, 0x23, 0xea, 0x00, 0xe6, 0xd7, 0x14, 0x09,
#   0xe7, 0xef, 0xf3, 0xe1, 0xd7, 0xee, 0x04, 0xf9, 0xd7, 0xfe, 0xec, 0xf6,
#   0xe8, 0xf2, 0xfb, 0xef, 0xf8, 0xeb, 0x10, 0xe9, 0x09, 0xe9, 0xf1, 0xf1,
#   0xe0, 0xfb, 0xfb, 0xfe, 0xf6, 0xe9, 0xf9, 0x06, 0xff, 0x0d, 0x19, 0xed,
#   0xe4, 0xf7, 0x13, 0xfd, 0xf1, 0xf9, 0x10, 0xfd, 0xeb, 0xfa, 0xeb, 0xea,
#   0xf1, 0x0a, 0xf9, 0xf7, 0xfa, 0xeb, 0x03, 0xf1, 0xee, 0x03, 0x06, 0x01,
#   0xfb, 0xf7, 0xf8, 0xf5, 0xdb, 0x0f, 0x01, 0xf1, 0xdb, 0x10, 0x09, 0x1a,
#   0x05, 0xf5, 0x15, 0x0c, 0x05, 0x01, 0xe6, 0xef, 0x0e, 0x04, 0x04, 0xf4,
#   0xe9, 0xfd, 0x00, 0x11, 0xfa, 0xed, 0x0d, 0xe5, 0xea, 0x04, 0x01, 0x06,
#   0xf8, 0x0e, 0x0a, 0xe4, 0xdd, 0xea, 0xff, 0x15, 0x06, 0xfb, 0xe2, 0xf1,
#   0xea, 0xfd, 0x00, 0x25, 0x0a, 0x0f, 0xf7, 0xd6, 0xed, 0xf4, 0x1a, 0x11,
#   0xf6, 0xf8, 0x05, 0x03, 0xfc, 0xd6, 0xf5, 0x00, 0x1c, 0xf7, 0xe9, 0xfc,
#   0xeb, 0xee, 0x21, 0x03, 0x1e, 0xe1, 0xe0, 0xec, 0x0b, 0xd5, 0xdc, 0x08,
#   0xfe, 0xfc, 0xf5, 0xea, 0x0e, 0xf1, 0x06, 0xff, 0xdf, 0x18, 0x15, 0x00,
#   0xfd, 0xdc, 0xfb, 0x02, 0x0c, 0xfb, 0x13, 0xff, 0xde, 0xed, 0x01, 0xf4,
#   0xfa, 0x02, 0xfd, 0xf6, 0xf1, 0x04, 0xea, 0xe7, 0xf3, 0x04, 0xfc, 0x05,
#   0xf6, 0xf7, 0xef, 0xeb, 0xf5, 0x14, 0xdd, 0xe1, 0xf3, 0x04, 0xfb, 0x02,
#   0xea, 0x24, 0xe9, 0xf0, 0x00, 0xf4, 0x0f, 0xe8, 0xfd, 0x03, 0x07, 0xf2,
#   0xef, 0x07, 0xf2, 0x00, 0x06, 0xec, 0xf4, 0x22, 0xeb, 0x07, 0xda, 0xfc,
#   0xe2, 0x0e, 0x02, 0xd3, 0xe5, 0xfb, 0x02, 0xf4, 0xfc, 0x1a, 0x0c, 0xf1,
#   0xdf, 0x01, 0x19, 0xf7, 0xf1, 0x1a, 0xff, 0x11, 0xfa, 0x01, 0x0e, 0x04,
#   0x15, 0xff, 0x10, 0xf2, 0x10, 0xf5, 0xfb, 0xe1, 0x0c, 0x01, 0xf5, 0xf6,
#   0xca, 0xef, 0x00, 0xf3, 0xf7, 0x0c, 0x03, 0xe0, 0xf1, 0xf9, 0xf1, 0xf7,
#   0x04, 0xf5, 0xf1, 0xf2, 0xd2, 0xf2, 0xfd, 0x00, 0xf9, 0xfd, 0x13, 0x1d,
#   0xfa, 0xf5, 0x0b, 0x00, 0xf6, 0x0d, 0x1a, 0xcc, 0xf6, 0xdf, 0xfc, 0xec,
#   0xea, 0x07, 0xf2, 0xdf, 0xf0, 0xf6, 0x02, 0x08, 0x08, 0x0c, 0xf0, 0x06,
#   0xe7, 0xf6, 0x0d, 0xfd, 0xef, 0x12, 0xf2, 0x0d, 0xfe, 0xe3, 0x0f, 0x0d,
#   0xd8, 0xfa, 0xf3, 0xda, 0xce, 0xeb, 0x14, 0xf4, 0xdc, 0xea, 0xf8, 0xf7,
#   0x00, 0xe6, 0x0c, 0xdd, 0xd4, 0xf2, 0x0b, 0xf5, 0x04, 0xec, 0x04, 0xe6,
#   0xf1, 0x18, 0x19, 0x02, 0xed, 0xf9, 0x14, 0x0f, 0x00, 0x27, 0xf9, 0xd4,
#   0x00, 0xff, 0xfa, 0xfe, 0xfc, 0x2a, 0x15, 0xed, 0xe7, 0xff, 0x0d, 0x21,
#   0xe4, 0x18, 0x11, 0xfb, 0xe5, 0xf4, 0x17, 0x10, 0xee, 0x21, 0xf0, 0x01,
#   0xea, 0xec, 0x00, 0xf7, 0xf6, 0x07, 0xf5, 0xee, 0xfb, 0xfa, 0x15, 0x08,
#   0xfa, 0x29, 0x03, 0x12, 0xef, 0x0b, 0xf6, 0x02, 0xf3, 0x16, 0x15, 0xf3,
#   0xfa, 0xfd, 0xfd, 0x05, 0x12, 0x02, 0xff, 0xc8, 0x06, 0xf0, 0x07, 0xf5,
#   0xfc, 0x02, 0xf6, 0xd4, 0xef, 0xc5, 0xf4, 0x20, 0x0a, 0xf1, 0xe8, 0xed,
#   0xcb, 0xdc, 0xf3, 0x04, 0x0e, 0x0b, 0x0a, 0xd4, 0xef, 0xd5, 0x11, 0x16,
#   0xf4, 0x06, 0xf6, 0xe9, 0xed, 0xf0, 0x07, 0xde, 0x0c, 0x09, 0xe6, 0xe5,
#   0xf0, 0xe4, 0x01, 0x25, 0xf3, 0x1b, 0xe8, 0xcf, 0xd3, 0xd4, 0x05, 0x12,
#   0x09, 0x07, 0xf1, 0xed, 0xc6, 0xe0, 0xe3, 0x05, 0xe7, 0x23, 0xfc, 0xf6,
#   0xd9, 0xe8, 0x06, 0x07, 0xef, 0x21, 0xe0, 0xef, 0xf1, 0xe8, 0x1d, 0x01,
#   0xe4, 0xf8, 0x00, 0x01, 0xcd, 0xf8, 0x00, 0x0a, 0xe0, 0xf6, 0x06, 0xff,
#   0xc6, 0xf9, 0x22, 0x03, 0xf3, 0xfd, 0x13, 0xed, 0xf4, 0xf6, 0x06, 0xef,
#   0xe5, 0xfe, 0xf6, 0x0a, 0xef, 0xf6, 0x04, 0x14, 0xdd, 0x2e, 0x09, 0xfa,
#   0xdc, 0x15, 0x0e, 0xf8, 0xd2, 0x20, 0x03, 0x08, 0xf0, 0xec, 0xfb, 0xee,
#   0xf3, 0x26, 0x14, 0xec, 0xec, 0xfd, 0x0e, 0x01, 0xe8, 0x09, 0x1d, 0xf6,
#   0xdd, 0xfe, 0xf5, 0xf7, 0xdb, 0x25, 0x14, 0xf4, 0xe2, 0x08, 0x0d, 0xff,
#   0xf7, 0x1b, 0x10, 0xf6, 0x05, 0xfd, 0x00, 0x02, 0x08, 0xe7, 0xef, 0xd5,
#   0x02, 0x16, 0xfe, 0xfd, 0x03, 0x10, 0xed, 0xf3, 0xf9, 0xd7, 0xf3, 0xfb,
#   0xf2, 0xfe, 0xf8, 0xe1, 0xfb, 0xfc, 0xfa, 0x00, 0xfb, 0x14, 0x06, 0xf9,
#   0xde, 0xe2, 0x0e, 0x10, 0x02, 0x18, 0x04, 0xf9, 0xce, 0xe6, 0x20, 0x16,
#   0xf9, 0x17, 0x0b, 0xd2, 0xd0, 0xd2, 0xfa, 0x05, 0xfc, 0x00, 0x1b, 0x03,
#   0xc9, 0xd9, 0x11, 0xfb, 0xe4, 0x27, 0xce, 0xe7, 0xe8, 0xe8, 0x15, 0x0d,
#   0xfc, 0x25, 0xff, 0xef, 0xe0, 0xee, 0xf8, 0xf6, 0xf0, 0x16, 0xf5, 0x0d,
#   0xf9, 0xed, 0x07, 0x21, 0xf3, 0xf1, 0x04, 0x03, 0x00, 0xdc, 0x02, 0x12,
#   0xf4, 0x12, 0xe7, 0xfd, 0xf9, 0xef, 0x0b, 0x15, 0xfb, 0x14, 0xe5, 0x0c,
#   0xee, 0xfc, 0x04, 0x07, 0xd8, 0x18, 0x0b, 0x06, 0xf3, 0xfc, 0xf9, 0x04,
#   0xf5, 0x10, 0x00, 0xe1, 0x00, 0xec, 0x1b, 0x03, 0xe6, 0x1e, 0x1d, 0xf7,
#   0xfe, 0xf9, 0xf4, 0x06, 0xf3, 0x04, 0x05, 0xd6, 0xe8, 0x06, 0x16, 0x25,
#   0x04, 0x0d, 0x0d, 0xfe, 0xe8, 0xfc, 0x16, 0x0b, 0xe9, 0x32, 0x07, 0xee,
#   0xf0, 0x0e, 0x13, 0x24, 0x06, 0xf3, 0x11, 0xfc, 0x0b, 0x0a, 0x29, 0x02,
#   0x05, 0x1c, 0xeb, 0xf1, 0xf9, 0x0a, 0xf2, 0xff, 0x06, 0xfd, 0xd5, 0xe0,
#   0xcf, 0xd2, 0xfd, 0xfc, 0x06, 0xe2, 0xf8, 0xc4, 0xdf, 0xe6, 0xf6, 0x0b,
#   0xef, 0x16, 0xef, 0xd6, 0xc7, 0xef, 0x14, 0x00, 0xf8, 0x15, 0x02, 0xf0,
#   0xf6, 0xf2, 0xf2, 0x03, 0xfc, 0x17, 0x08, 0xe8, 0x02, 0xf8, 0xfc, 0xea,
#   0x07, 0x1f, 0xed, 0xfa, 0xf0, 0xdd, 0x10, 0x00, 0x06, 0x01, 0xe4, 0x06,
#   0xe6, 0xd3, 0x1a, 0x0e, 0xeb, 0x11, 0x0d, 0xdb, 0xff, 0xdf, 0x15, 0x11,
#   0xe9, 0x13, 0x04, 0xf0, 0xe0, 0xd4, 0xf8, 0xef, 0xe9, 0xf6, 0xfc, 0xfb,
#   0xe5, 0xe0, 0xfc, 0x07, 0xed, 0x07, 0xea, 0x01, 0x00, 0xec, 0x00, 0x08,
#   0xfb, 0x18, 0x05, 0x04, 0xdf, 0xfd, 0xea, 0xe7, 0xe0, 0x07, 0xf4, 0xe2,
#   0x03, 0x09, 0x10, 0x0d, 0xf7, 0x20, 0x10, 0x07, 0x07, 0x06, 0xfc, 0xf7,
#   0xdc, 0x1e, 0x04, 0x13, 0xe9, 0xe7, 0xf3, 0x0e, 0xed, 0x17, 0x1d, 0x15,
#   0xe2, 0xf3, 0x08, 0x0b, 0xd1, 0x10, 0x06, 0xec, 0xef, 0xfb, 0xf7, 0x06,
#   0xf7, 0x19, 0x11, 0x18, 0xef, 0x03, 0x19, 0xf5, 0x23, 0x0b, 0x20, 0xe2,
#   0xf1, 0xea, 0x0d, 0x03, 0xf9, 0xfe, 0xd3, 0xe1, 0xf1, 0xda, 0xf3, 0x10,
#   0x13, 0xfc, 0xf1, 0xe8, 0xfd, 0xc0, 0xea, 0x1a, 0xf0, 0xf5, 0xfd, 0xcc,
#   0xd8, 0xda, 0xfb, 0x09, 0x14, 0x22, 0xe2, 0xfa, 0xe1, 0xdd, 0x12, 0x08,
#   0xe4, 0x12, 0x0e, 0xfb, 0xfe, 0xe7, 0x15, 0x0b, 0xec, 0x20, 0xe2, 0x00,
#   0xe7, 0xea, 0xfc, 0xf3, 0xf2, 0x0c, 0xfe, 0xe2, 0xe7, 0xe5, 0xf6, 0x1d,
#   0xff, 0x1f, 0xd4, 0x0b, 0xe2, 0xdd, 0xf8, 0xf9, 0xd8, 0x13, 0xec, 0x05,
#   0xcd, 0xc1, 0xfb, 0x0a, 0xd3, 0xf9, 0xec, 0xe3, 0x07, 0xe4, 0x12, 0x06,
#   0xfa, 0xf5, 0x02, 0x06, 0xd5, 0xf7, 0x12, 0xfe, 0xec, 0x0d, 0xfc, 0x01,
#   0x02, 0xfa, 0x02, 0xfd, 0xeb, 0x1c, 0x07, 0xf6, 0xd6, 0xfb, 0xeb, 0xf9,
#   0xd3, 0x22, 0xf7, 0xee, 0xeb, 0xf1, 0x06, 0xea, 0xe0, 0x2e, 0x05, 0xfb,
#   0xdb, 0xf4, 0x16, 0xff, 0xe3, 0x25, 0xf0, 0xd3, 0xf2, 0xe8, 0x06, 0xef,
#   0xe5, 0x05, 0x08, 0xe7, 0xe4, 0xe2, 0x21, 0x01, 0xea, 0x15, 0x04, 0xfc,
#   0xea, 0xda, 0x07, 0x1b, 0xfc, 0x0e, 0x0e, 0xfc, 0xee, 0xf2, 0x18, 0x0e,
#   0x03, 0x1b, 0x13, 0xe0, 0xf8, 0xea, 0x1a, 0xfb, 0x01, 0x02, 0x08, 0xed,
#   0xf9, 0xcd, 0xef, 0x02, 0x0c, 0x03, 0xf9, 0xf5, 0xe8, 0xc6, 0xfd, 0xfb,
#   0xfc, 0x12, 0xf7, 0xe0, 0xcc, 0xf5, 0xfd, 0x14, 0x01, 0x0c, 0xfc, 0x02,
#   0xfe, 0xdd, 0x19, 0xfe, 0xd7, 0x19, 0x00, 0xed, 0xd6, 0xd8, 0x22, 0x17,
#   0xf6, 0x0b, 0xf1, 0x05, 0xe5, 0xea, 0xf6, 0x15, 0xf3, 0x1d, 0xf8, 0xe9,
#   0xd9, 0xe9, 0x11, 0xf2, 0x18, 0xf6, 0xf4, 0x1c, 0xd5, 0xdb, 0xf2, 0xfb,
#   0xef, 0x16, 0x09, 0xe7, 0x06, 0xd9, 0xf9, 0x11, 0xf4, 0x25, 0x15, 0xf5,
#   0x04, 0xe2, 0xf7, 0x19, 0xe4, 0x17, 0xf1, 0x06, 0xfe, 0xe1, 0xf5, 0x17,
#   0xe3, 0x0e, 0x04, 0x05, 0x06, 0xd8, 0x20, 0x12, 0xdf, 0x01, 0xf9, 0xe1,
#   0xe0, 0x07, 0xf8, 0x09, 0xe1, 0x1f, 0xd7, 0x0d, 0xfc, 0xf1, 0xfe, 0x04,
#   0xda, 0x34, 0xf9, 0xf5, 0x0d, 0xf7, 0x1b, 0xf7, 0xde, 0x22, 0xf9, 0x01,
#   0xf3, 0xec, 0x11, 0x0b, 0xe8, 0x28, 0xfa, 0x02, 0xd4, 0xf7, 0x04, 0x03,
#   0xdc, 0x20, 0x15, 0xef, 0xfe, 0xee, 0x00, 0x1d, 0xf1, 0x0c, 0xf8, 0x00,
#   0xef, 0xf1, 0x19, 0x29, 0xf3, 0x0f, 0x17, 0xe2, 0xe8, 0xec, 0x17, 0x13,
#   0x10, 0xf5, 0x01, 0xe1, 0x02, 0xec, 0xdd, 0xff, 0x16, 0x00, 0xf2, 0xd0,
#   0xd7, 0xdc, 0xd8, 0xf9, 0xfc, 0x01, 0xfe, 0xdc, 0xeb, 0xf5, 0x11, 0x05,
#   0x02, 0x00, 0xe8, 0xf4, 0xbf, 0xdb, 0x10, 0x13, 0xe2, 0x12, 0xfa, 0x03,
#   0xdf, 0xe3, 0x0e, 0xfd, 0xde, 0x11, 0xf5, 0x00, 0xf4, 0xc9, 0xfe, 0x19,
#   0xd7, 0x18, 0x08, 0x04, 0xdc, 0xe4, 0x09, 0xfc, 0xef, 0x15, 0xdd, 0x1a,
#   0xd4, 0xcc, 0xf9, 0x17, 0xf5, 0x21, 0xf8, 0x02, 0xd0, 0xea, 0x20, 0x02,
#   0xf8, 0x19, 0xf1, 0x07, 0xec, 0xd7, 0xf9, 0xfb, 0xf4, 0x1f, 0x07, 0x16,
#   0xfe, 0xdc, 0x0d, 0x0f, 0xf5, 0x12, 0x01, 0xfb, 0xe7, 0xe1, 0xfa, 0x1c,
#   0x01, 0x0f, 0xf4, 0xfb, 0xec, 0xff, 0xfe, 0x01, 0xe0, 0x22, 0x13, 0xe7,
#   0x04, 0xf0, 0xf9, 0x04, 0xdf, 0x2b, 0xfa, 0xed, 0x0a, 0x07, 0x16, 0x17,
#   0xd1, 0x17, 0x0c, 0xee, 0x04, 0xf5, 0x18, 0x09, 0xd8, 0x24, 0xe2, 0xf9,
#   0xf1, 0xf6, 0xf3, 0xfe, 0xcf, 0x12, 0xfa, 0x11, 0xf1, 0x04, 0x12, 0x02,
#   0xee, 0x26, 0xee, 0xed, 0xf1, 0xf7, 0x2a, 0x07, 0xeb, 0x23, 0x1d, 0xf7,
#   0xee, 0xf7, 0x05, 0x0a, 0x19, 0xf8, 0xe5, 0x12, 0xef, 0xde, 0x19, 0xec,
#   0x06, 0x09, 0xea, 0xd5, 0xd9, 0xb7, 0x03, 0x0f, 0xfd, 0xf1, 0xe7, 0xfe,
#   0xda, 0xd8, 0x09, 0x0d, 0xe6, 0x19, 0xe7, 0x0e, 0xf5, 0xe4, 0x0f, 0x1c,
#   0xe8, 0x02, 0x1f, 0x05, 0xff, 0xf2, 0x0a, 0xf8, 0xeb, 0x24, 0xf8, 0xff,
#   0xe3, 0xda, 0xf0, 0x12, 0xd2, 0x00, 0xfd, 0xf7, 0xd9, 0xd2, 0x26, 0x13,
#   0xea, 0x26, 0xe9, 0x04, 0xd9, 0xdf, 0x10, 0x07, 0xdb, 0x1a, 0x09, 0xfa,
#   0xe9, 0xe9, 0xff, 0x0a, 0xf2, 0x16, 0xfd, 0xea, 0xe5, 0xd7, 0xf2, 0x26,
#   0xf2, 0x1a, 0x05, 0xf6, 0xce, 0xdf, 0x01, 0x11, 0xd7, 0x10, 0x00, 0xe8,
#   0xe1, 0xe3, 0x0d, 0x0f, 0xd6, 0x1b, 0xf2, 0xea, 0x02, 0xee, 0xfa, 0x1b,
#   0xf4, 0x2c, 0x00, 0x15, 0x16, 0x04, 0x16, 0xf3, 0xed, 0x12, 0x0c, 0xce,
#   0x19, 0x00, 0x0d, 0x07, 0xda, 0x19, 0x0e, 0x07, 0xe0, 0xef, 0x07, 0x00,
#   0xce, 0x27, 0xf1, 0xee, 0xe5, 0xdc, 0x13, 0x11, 0xf4, 0x2e, 0xf4, 0x11,
#   0xf8, 0xf6, 0x17, 0x22, 0xf6, 0x13, 0x19, 0xf0, 0xf0, 0xe6, 0x32, 0x14,
#   0xd5, 0x2a, 0x13, 0xf9, 0xf5, 0xed, 0x05, 0x08, 0x13, 0xfb, 0xfb, 0x09,
#   0xff, 0xca, 0x0c, 0x13, 0xf6, 0x06, 0xf7, 0x02, 0xc4, 0xc9, 0x0e, 0x07,
#   0xf9, 0xfc, 0xd4, 0xe0, 0xe0, 0xe9, 0x07, 0x17, 0x05, 0x08, 0xe9, 0xf6,
#   0xdc, 0xf1, 0x0a, 0xf1, 0xf6, 0x04, 0xf7, 0xfc, 0xff, 0xed, 0x0d, 0x00,
#   0xe3, 0x10, 0xfd, 0xed, 0xff, 0xd9, 0x15, 0x0a, 0xec, 0x02, 0xea, 0xf7,
#   0xed, 0xd6, 0x05, 0x04, 0x03, 0x0a, 0xdf, 0x0b, 0xea, 0xd1, 0x0a, 0x28,
#   0xdf, 0x22, 0xf1, 0x00, 0xf0, 0xef, 0x15, 0x0c, 0xdd, 0x17, 0xdc, 0xe7,
#   0xe3, 0xe5, 0x05, 0xfb, 0xf1, 0x04, 0xfb, 0x09, 0xe6, 0xe0, 0xfe, 0x1b,
#   0xc8, 0x1e, 0xec, 0xfb, 0xf9, 0xf1, 0x06, 0x0b, 0xef, 0x23, 0x12, 0x09,
#   0xda, 0xf7, 0xfa, 0xfe, 0xcf, 0x1c, 0x1c, 0xff, 0x0a, 0xfa, 0x17, 0x27,
#   0xed, 0xf2, 0x03, 0x09, 0x1d, 0x02, 0x13, 0x13, 0xdb, 0x1c, 0x05, 0xe6,
#   0x05, 0xe4, 0x11, 0xfe, 0xe1, 0x2b, 0xeb, 0xf0, 0xf9, 0xf9, 0x04, 0x16,
#   0xe4, 0x25, 0x10, 0xfd, 0xe6, 0xde, 0x14, 0x10, 0xf0, 0x26, 0x16, 0xf7,
#   0xef, 0xea, 0x01, 0x1a, 0xe5, 0x2a, 0x16, 0xd5, 0xf1, 0xe1, 0x08, 0x0d,
#   0x21, 0x01, 0x0c, 0xe9, 0xf8, 0xbf, 0x13, 0x11, 0xf7, 0xe3, 0xfd, 0xea,
#   0xd8, 0xc2, 0xe9, 0x0c, 0xfc, 0xf7, 0xee, 0xe1, 0xea, 0xec, 0xed, 0x17,
#   0xe5, 0x02, 0xf1, 0xe6, 0xed, 0xca, 0x0b, 0x0b, 0xd9, 0x1a, 0xf4, 0x06,
#   0xd2, 0xc2, 0xfb, 0x12, 0xdc, 0x0a, 0xf4, 0xdf, 0x00, 0xdc, 0x11, 0x0e,
#   0xdc, 0x10, 0x05, 0xdb, 0xd6, 0xdf, 0x0d, 0x05, 0xf0, 0x26, 0xde, 0xf7,
#   0xf7, 0xe9, 0xec, 0x0d, 0xd3, 0x18, 0xf4, 0x02, 0x10, 0xdb, 0xdf, 0x14,
#   0xdb, 0x0c, 0xfe, 0xee, 0xf1, 0xcc, 0xfc, 0x06, 0xc3, 0x16, 0xfa, 0xe7,
#   0xf4, 0xcf, 0x05, 0x0e, 0xdb, 0x0d, 0x04, 0x14, 0xfd, 0xd8, 0x06, 0x09,
#   0xe1, 0x15, 0x04, 0x07, 0xfa, 0xd4, 0x17, 0x08, 0xe1, 0x27, 0x11, 0xf6,
#   0x0a, 0x09, 0x12, 0x05, 0xdf, 0x27, 0xf9, 0xf7, 0xfd, 0x00, 0xf7, 0xff,
#   0xe6, 0x0a, 0x0e, 0x0a, 0xfa, 0xf3, 0x10, 0xf5, 0xeb, 0x2b, 0x06, 0xe3,
#   0xe2, 0xfd, 0x2c, 0x10, 0xe3, 0x11, 0x11, 0xf9, 0xf6, 0xe7, 0x19, 0x26,
#   0xf3, 0x27, 0x09, 0xf7, 0x0d, 0xed, 0x22, 0x09, 0xe5, 0x14, 0x18, 0xdb,
#   0xed, 0xdf, 0x17, 0x09, 0x13, 0xf8, 0xed, 0x10, 0xff, 0xd9, 0x1a, 0x01,
#   0x0c, 0x05, 0xf1, 0xec, 0xfa, 0xd4, 0x03, 0xee, 0xf2, 0x10, 0xe9, 0xe4,
#   0xef, 0xd6, 0xee, 0xf3, 0xf6, 0x13, 0xf4, 0xf8, 0xdc, 0xde, 0xf0, 0xf6,
#   0xee, 0x1c, 0xf8, 0x07, 0xe2, 0xd4, 0x09, 0xfa, 0xe5, 0x0b, 0x1d, 0xe3,
#   0xea, 0xdc, 0xfa, 0xf2, 0xdd, 0x0b, 0xf6, 0xfb, 0xdf, 0xde, 0x1c, 0x0a,
#   0xee, 0xee, 0xe7, 0x06, 0xcd, 0xde, 0xf3, 0x0c, 0xdb, 0xfb, 0xfd, 0x09,
#   0xfe, 0xdd, 0xfa, 0xfd, 0x04, 0x0b, 0xf0, 0xf5, 0xdf, 0xdb, 0xf8, 0x10,
#   0xdf, 0xdb, 0x20, 0x0a, 0xf2, 0xe2, 0x03, 0xf7, 0xcc, 0x21, 0x19, 0xff,
#   0xf7, 0xe3, 0x16, 0x00, 0xeb, 0x04, 0x08, 0x06, 0x08, 0xf9, 0x18, 0x19,
#   0xd0, 0x1c, 0xf6, 0x29, 0xf4, 0x00, 0x15, 0xfc, 0xed, 0x0d, 0xff, 0x12,
#   0xf5, 0x00, 0x12, 0x06, 0x00, 0x3b, 0x06, 0x0d, 0xf5, 0xd8, 0x17, 0x0d,
#   0xcf, 0x13, 0xf2, 0xfd, 0xf8, 0xf6, 0x27, 0x0b, 0xe8, 0x1a, 0x00, 0xf1,
#   0x0e, 0x09, 0x21, 0xf4, 0x12, 0x0c, 0x07, 0xff, 0x04, 0xf8, 0x18, 0x02,
#   0xe5, 0x15, 0x1e, 0xef, 0xfa, 0xe5, 0x15, 0xf8, 0x07, 0x08, 0x0a, 0xff,
#   0xfa, 0xc5, 0x01, 0xf5, 0x06, 0xee, 0xd6, 0xdf, 0xd5, 0xc6, 0xec, 0x09,
#   0xfa, 0xf3, 0xe7, 0xf3, 0xe1, 0xe7, 0xf5, 0x03, 0xe8, 0x12, 0xf1, 0x14,
#   0xea, 0xdd, 0xe8, 0x08, 0xd5, 0x25, 0xfb, 0x06, 0xea, 0xcd, 0x11, 0xf6,
#   0xee, 0x06, 0x12, 0x05, 0xfa, 0xe3, 0xf3, 0x0c, 0xd8, 0x03, 0x0b, 0xfc,
#   0xed, 0xe6, 0x15, 0x1e, 0xd9, 0x16, 0xea, 0xed, 0xe4, 0xd2, 0xde, 0xf8,
#   0xd3, 0x11, 0xfb, 0x1c, 0x0e, 0xd1, 0xfe, 0x06, 0xee, 0x14, 0xe9, 0xf1,
#   0xcb, 0xce, 0x10, 0x08, 0xe2, 0x04, 0x04, 0xfd, 0xf7, 0xdd, 0x15, 0x0d,
#   0xce, 0x15, 0x06, 0xf5, 0xfe, 0xf3, 0x26, 0x09, 0xe3, 0x1b, 0xee, 0x1f,
#   0xf1, 0xfd, 0xfe, 0x18, 0xd3, 0x0a, 0xf7, 0xf5, 0xf1, 0xe3, 0x18, 0x10,
#   0xf5, 0x29, 0x07, 0x1a, 0x0e, 0xe8, 0x06, 0x26, 0xdc, 0x38, 0x18, 0xf1,
#   0x05, 0xe9, 0x10, 0x15, 0xc9, 0x28, 0x0b, 0xf2, 0xee, 0xee, 0x1c, 0x16,
#   0xf5, 0x00, 0x07, 0xf7, 0xfe, 0xfe, 0x10, 0x24, 0xe3, 0x2e, 0x07, 0xef,
#   0x06, 0xe9, 0x08, 0x1d, 0xc3, 0x22, 0x02, 0xe4, 0xed, 0xec, 0x07, 0xf9,
#   0x1a, 0x08, 0x09, 0xfb, 0xdc, 0xa8, 0x1b, 0xfe, 0x12, 0xf2, 0xec, 0xee,
#   0xe4, 0xc6, 0xfd, 0xeb, 0xda, 0x10, 0xf9, 0xf2, 0xe1, 0xd8, 0xfa, 0xf4,
#   0xea, 0xfa, 0xda, 0xf1, 0xf5, 0xc7, 0xfb, 0x0c, 0xcb, 0xf3, 0xe4, 0x06,
#   0xec, 0xcf, 0x18, 0xf5, 0xde, 0xed, 0xf9, 0xfa, 0xe6, 0xd5, 0x19, 0x04,
#   0xd8, 0x01, 0xf4, 0x0b, 0xf1, 0xcb, 0x09, 0x06, 0xdc, 0x04, 0xea, 0x09,
#   0xf2, 0xcb, 0x0a, 0x13, 0xd6, 0xfe, 0x07, 0x03, 0xec, 0xe5, 0x0f, 0x01,
#   0xd1, 0x05, 0x06, 0xfb, 0xf0, 0xce, 0xf9, 0x0a, 0xd0, 0xff, 0xfc, 0xfb,
#   0x27, 0xe6, 0x03, 0xe8, 0xc8, 0x14, 0x10, 0xe4, 0x07, 0xd5, 0x12, 0x08,
#   0xd5, 0x1b, 0x03, 0x16, 0xf9, 0xe6, 0xf3, 0x18, 0xd5, 0x06, 0xff, 0x10,
#   0x15, 0xe8, 0x01, 0xfc, 0xc8, 0x1f, 0xec, 0x09, 0xf0, 0x07, 0x1a, 0x11,
#   0xdd, 0x0c, 0x00, 0x11, 0xe7, 0xea, 0x18, 0x0c, 0xe4, 0x17, 0xeb, 0x0f,
#   0xf3, 0xff, 0x0e, 0x20, 0xe2, 0x25, 0x12, 0x15, 0xff, 0xf1, 0x0e, 0x17,
#   0xda, 0x08, 0x05, 0x16, 0x1d, 0xf7, 0x29, 0x25, 0xcd, 0x0c, 0x10, 0xf5,
#   0xf7, 0xe0, 0x1c, 0x27, 0x0f, 0xf3, 0x02, 0xf2, 0xd1, 0x9a, 0x03, 0x26,
#   0xfb, 0xdc, 0xf8, 0xd6, 0xd7, 0xad, 0xe8, 0x1e, 0x02, 0xf8, 0xff, 0xd3,
#   0xe2, 0xe4, 0xec, 0x01, 0xe2, 0xf3, 0xe5, 0x08, 0xe1, 0xe0, 0xf9, 0x00,
#   0xe0, 0x14, 0x02, 0x1f, 0x14, 0xd7, 0x12, 0xfd, 0xe1, 0x08, 0xf9, 0x0f,
#   0xf1, 0xce, 0xf3, 0x08, 0xcd, 0x22, 0xfa, 0xf6, 0xfa, 0xca, 0x01, 0x03,
#   0xf2, 0xfc, 0xff, 0x28, 0xec, 0xdb, 0x0b, 0x15, 0xe2, 0x14, 0x00, 0xf8,
#   0xfe, 0xf2, 0xfa, 0x07, 0xdf, 0x06, 0xe6, 0x06, 0x12, 0xcb, 0x24, 0x10,
#   0xd9, 0x15, 0x00, 0xec, 0x09, 0xe1, 0x09, 0xfa, 0xc7, 0x15, 0xfc, 0x01,
#   0x00, 0xdf, 0xf5, 0x02, 0xee, 0xf9, 0x02, 0x14, 0xf1, 0xda, 0x00, 0x02,
#   0xcc, 0x09, 0x0b, 0x11, 0x02, 0xf4, 0x0d, 0xf5, 0xd3, 0x0e, 0x17, 0x0a,
#   0x18, 0xed, 0x23, 0x03, 0xcd, 0x05, 0xfc, 0xf4, 0xfd, 0xf3, 0x21, 0x1a,
#   0xca, 0x1a, 0xf9, 0xfd, 0xef, 0xe3, 0x11, 0x14, 0xd8, 0x1c, 0xef, 0xf5,
#   0x12, 0xf8, 0x18, 0x05, 0xe6, 0x0c, 0x1f, 0x16, 0x11, 0xe2, 0x0e, 0x05,
#   0xce, 0x24, 0x0a, 0xf3, 0xe6, 0xf5, 0x10, 0x15, 0x15, 0xf4, 0x0f, 0xd0,
#   0xf9, 0x81, 0x00, 0x13, 0xff, 0xfd, 0xf9, 0xde, 0xe5, 0xaf, 0xf4, 0x01,
#   0x05, 0xf9, 0xf0, 0xdb, 0xce, 0xfa, 0x0b, 0x11, 0xe7, 0x06, 0xdd, 0xf6,
#   0xf8, 0xd8, 0xfc, 0x14, 0xdd, 0x03, 0xfc, 0x1c, 0xf4, 0xd9, 0xfa, 0x05,
#   0xc8, 0x03, 0xff, 0x0d, 0xff, 0xd4, 0x0c, 0x11, 0xdb, 0xf0, 0x09, 0xfd,
#   0x0d, 0xe0, 0x05, 0x0b, 0xdc, 0x04, 0xf5, 0x0a, 0xe7, 0xd4, 0xf9, 0x0a,
#   0xd2, 0xfc, 0xef, 0xf6, 0x03, 0xea, 0x00, 0x1d, 0xe9, 0x05, 0xfe, 0xf9,
#   0x0b, 0xe9, 0xfa, 0x00, 0xdc, 0xfb, 0xea, 0x00, 0x15, 0xdc, 0x04, 0x00,
#   0xde, 0x14, 0xf5, 0x17, 0x0a, 0xec, 0x03, 0x01, 0xe1, 0x18, 0xfe, 0xfc,
#   0x1c, 0xd3, 0x16, 0x01, 0xe0, 0x2e, 0x0f, 0x0f, 0x21, 0xe7, 0x16, 0x0c,
#   0xce, 0x2e, 0x0a, 0xfe, 0x03, 0xf1, 0x18, 0x06, 0xcf, 0x07, 0xef, 0xf3,
#   0xee, 0xee, 0xfc, 0xfe, 0xd6, 0x10, 0x12, 0x03, 0x0c, 0xd9, 0x08, 0x1c,
#   0xce, 0x0a, 0xfa, 0xf5, 0x11, 0xf4, 0x15, 0x17, 0xed, 0x16, 0xfd, 0x01,
#   0x0b, 0x01, 0x01, 0x12, 0xe2, 0x22, 0xf9, 0xde, 0xed, 0xf5, 0x1b, 0x10,
#   0x00, 0x10, 0xf0, 0xd8, 0xd9, 0xcb, 0x07, 0x10, 0xe9, 0x11, 0xfa, 0xf1,
#   0xf4, 0xe8, 0xfb, 0x0a, 0xd3, 0x24, 0xfc, 0xd2, 0xea, 0x11, 0x07, 0x19,
#   0xf0, 0x16, 0xf1, 0xf0, 0xf7, 0x0a, 0xf4, 0x0f, 0xde, 0x13, 0x09, 0x23,
#   0xf2, 0x06, 0xfb, 0x0a, 0xd1, 0x19, 0xf2, 0xfa, 0xf0, 0x08, 0x04, 0x18,
#   0xe4, 0x12, 0xfd, 0xe4, 0xea, 0xfb, 0xff, 0x08, 0xe9, 0x01, 0x01, 0xd1,
#   0xeb, 0xf9, 0x0e, 0x00, 0xf0, 0x11, 0xf8, 0xf2, 0xe1, 0xfd, 0xfd, 0x08,
#   0x05, 0x13, 0xee, 0xff, 0xe7, 0x05, 0x03, 0xff, 0xd0, 0x05, 0xff, 0xfa,
#   0xec, 0xfb, 0xf7, 0x13, 0xdb, 0x0c, 0x13, 0xf3, 0xf6, 0x05, 0xfe, 0x08,
#   0xdb, 0x0a, 0x09, 0x13, 0x0b, 0xf8, 0x0e, 0x13, 0xf8, 0x0a, 0x14, 0x0d,
#   0x12, 0xfb, 0x14, 0x06, 0xde, 0xff, 0x17, 0x10, 0xe7, 0x04, 0x0e, 0x00,
#   0xdc, 0x09, 0x16, 0x10, 0xed, 0xf2, 0x0c, 0x0e, 0xf3, 0x00, 0x13, 0xf5,
#   0xee, 0x06, 0x05, 0x0a, 0xec, 0x08, 0xfe, 0xfa, 0xea, 0xfa, 0x21, 0x03,
#   0xec, 0xfa, 0x04, 0xf2, 0x0a, 0xfb, 0x05, 0x00, 0xfc, 0xfe, 0x0f, 0xf7,
#   0x0f, 0x08, 0x1a, 0x04, 0xfe, 0x0f, 0xfe, 0xef, 0x0b, 0x0b, 0x0c, 0x0c,
#   0x16, 0xeb, 0xe4, 0x07, 0x01, 0x0f, 0x00, 0xea, 0x0e, 0x01, 0xfe, 0xfe,
#   0xf1, 0xf6, 0xed, 0x20, 0x12, 0xf2, 0xf2, 0x23, 0x02, 0xfa, 0xfd, 0x02,
#   0xf2, 0x08, 0x06, 0x06, 0x0c, 0xeb, 0x02, 0x00, 0xfb, 0x04, 0xfe, 0xea,
#   0x11, 0xea, 0xfd, 0xf5, 0xe7, 0xfe, 0xf2, 0x05, 0xdd, 0xef, 0xfb, 0x1c,
#   0xfe, 0xf3, 0x02, 0xe9, 0x03, 0xf2, 0xee, 0x07, 0xf4, 0x06, 0x14, 0xe7,
#   0xe1, 0xf6, 0x06, 0xfd, 0x14, 0xfe, 0xee, 0x11, 0xfc, 0xfc, 0xef, 0x17,
#   0xe4, 0x02, 0x08, 0x12, 0xf4, 0xd8, 0x0b, 0x04, 0xf8, 0xfc, 0xf0, 0x0d,
#   0x04, 0x07, 0xf7, 0xf4, 0x12, 0xed, 0x06, 0xf9, 0x0b, 0x01, 0x03, 0xfc,
#   0x13, 0xfa, 0xe7, 0xeb, 0x08, 0xd9, 0xd9, 0xfa, 0xff, 0xf9, 0xeb, 0xfe,
#   0xf8, 0xdc, 0xf0, 0xf1, 0xcc, 0xf3, 0xf1, 0xfe, 0x05, 0xe4, 0xef, 0xf1,
#   0x09, 0xdc, 0x07, 0xec, 0xf7, 0x16, 0x04, 0xe9, 0x02, 0xf7, 0x05, 0x13,
#   0xdd, 0xf6, 0x12, 0x13, 0xf9, 0xf9, 0x01, 0xfb, 0x08, 0xe5, 0x08, 0xe3,
#   0xf7, 0xf2, 0x03, 0xce, 0x0f, 0x02, 0xfa, 0x0c, 0xf9, 0x04, 0x09, 0xee,
#   0x06, 0xf3, 0xfb, 0xfc, 0x0c, 0xe6, 0x0a, 0xf7, 0xec, 0xe2, 0xfa, 0xef,
#   0xfa, 0x04, 0x08, 0x13, 0xf3, 0xfc, 0xec, 0x0a, 0x07, 0x0e, 0x11, 0x00,
#   0x13, 0xf6, 0x13, 0x17, 0xed, 0xfd, 0x0e, 0xe8, 0xfb, 0x13, 0xd7, 0xee,
#   0xf4, 0x15, 0xfa, 0x0d, 0x02, 0xfb, 0xe7, 0x03, 0x02, 0xfe, 0xfe, 0xee,
#   0xe0, 0xfa, 0xfe, 0x02, 0x02, 0xfb, 0x02, 0xf0, 0xeb, 0xe3, 0xc3, 0x01,
#   0xeb, 0x0f, 0xea, 0xf6, 0xcb, 0x01, 0x00, 0xf9, 0xf0, 0xf1, 0xec, 0xff,
#   0xd7, 0xe3, 0xe8, 0xea, 0xef, 0xf6, 0x11, 0xfb, 0xe0, 0xf1, 0xee, 0xde,
#   0x13, 0xfa, 0xff, 0x09, 0x09, 0x0e, 0xf2, 0x10, 0xe8, 0x00, 0xe9, 0xec,
#   0xe0, 0xe1, 0xf0, 0xf9, 0xf0, 0xfd, 0xec, 0xfe, 0xff, 0xf8, 0xf8, 0x03,
#   0x00, 0x04, 0xf0, 0x20, 0x14, 0xff, 0xf7, 0xfc, 0x0f, 0xf6, 0xe9, 0x05,
#   0xf8, 0xf1, 0xf9, 0xf0, 0xf9, 0x00, 0xeb, 0xea, 0xff, 0xf7, 0xf3, 0x03,
#   0xe1, 0xe9, 0xee, 0xda, 0xff, 0xe0, 0xf2, 0xfe, 0xf0, 0xd1, 0x06, 0x14,
#   0xbd, 0xfc, 0xdf, 0xfa, 0xf3, 0x0d, 0x0c, 0xfe, 0xfb, 0xfd, 0x07, 0xd0,
#   0xf5, 0xdf, 0xd6, 0xea, 0x25, 0x0f, 0x05, 0x0e, 0x04, 0x00, 0x1d, 0x09,
#   0x06, 0xfe, 0x04, 0x1f, 0xfe, 0x06, 0xff, 0x02, 0xfc, 0xfc, 0xfd, 0xea,
#   0x19, 0x25, 0xed, 0x0d, 0xf4, 0xe7, 0xf4, 0xed, 0x08, 0xee, 0xf5, 0x02,
#   0xfa, 0x01, 0xe3, 0xfb, 0x01, 0xef, 0xfa, 0xfe, 0x10, 0xe8, 0xe7, 0xf4,
#   0x14, 0x14, 0xea, 0x18, 0xe1, 0xfb, 0xfa, 0xe2, 0xda, 0xf0, 0xf6, 0xf1,
#   0xed, 0xf4, 0x02, 0x08, 0xf7, 0xf4, 0xdf, 0xed, 0xe3, 0x08, 0x05, 0xfd,
#   0xef, 0x1a, 0xe6, 0xf1, 0x0d, 0x0a, 0x25, 0xf3, 0xe1, 0xfc, 0xfd, 0xf2,
#   0x02, 0xed, 0xe3, 0x0a, 0x06, 0xe2, 0xf3, 0xfb, 0xd9, 0xfd, 0xef, 0x06,
#   0x03, 0xef, 0xea, 0x00, 0xe4, 0x06, 0x09, 0xe1, 0x0e, 0xf2, 0xef, 0xfb,
#   0x00, 0xf8, 0xcf, 0xfb, 0xfa, 0xf3, 0xfd, 0xc7, 0xf0, 0xff, 0xfa, 0x07,
#   0xf7, 0xf0, 0xf2, 0x10, 0xfe, 0xf7, 0xf7, 0x01, 0xdf, 0x03, 0xf0, 0xdb,
#   0xf5, 0xf4, 0xf3, 0x0c, 0xeb, 0xf3, 0xf7, 0xf5, 0xf7, 0xf0, 0x12, 0x02,
#   0xff, 0x1d, 0xfa, 0xea, 0xe7, 0xfc, 0xfb, 0x07, 0xf0, 0xf5, 0xfd, 0xf5,
#   0xfe, 0xfc, 0xf0, 0xf9, 0xf6, 0xf3, 0x0a, 0xf2, 0xed, 0xfe, 0x12, 0xf5,
#   0x0f, 0xfd, 0x12, 0xfa, 0x0c, 0xf3, 0xfa, 0x11, 0x0d, 0xfa, 0xf3, 0xee,
#   0xee, 0x05, 0x1c, 0xf6, 0x0a, 0xdb, 0xf6, 0xde, 0xeb, 0xfb, 0xff, 0xe6,
#   0x11, 0xf7, 0xff, 0xe3, 0xdf, 0xe6, 0xef, 0x15, 0xfd, 0x00, 0x0b, 0x04,
#   0x19, 0x17, 0xe1, 0xff, 0xe0, 0xe6, 0x05, 0x01, 0x04, 0xfa, 0x09, 0xf7,
#   0xca, 0x0c, 0xed, 0xf5, 0xdc, 0xf3, 0xea, 0x03, 0xeb, 0xe8, 0xf0, 0xf2,
#   0xdb, 0x0e, 0xd7, 0x01, 0xdf, 0xe0, 0xdc, 0xea, 0xdf, 0x06, 0xbe, 0xf4,
#   0xf4, 0xfb, 0x03, 0xf0, 0xe1, 0xfb, 0xe8, 0xfa, 0xfb, 0xe9, 0x1b, 0x06,
#   0x18, 0x02, 0xf5, 0x04, 0xdc, 0xf3, 0xfe, 0xc8, 0x10, 0x0a, 0xfc, 0xf2,
#   0x0d, 0x08, 0xf8, 0x09, 0x0a, 0xff, 0xfd, 0xf7, 0x07, 0xef, 0x07, 0x03,
#   0xe6, 0xeb, 0x02, 0xf0, 0xd4, 0xf0, 0xfc, 0xe4, 0xe2, 0xe2, 0x03, 0xea,
#   0x04, 0xff, 0xe0, 0xf3, 0xed, 0xd9, 0xd9, 0xfe, 0x0e, 0xeb, 0xd8, 0x0e,
#   0xf5, 0xfa, 0x02, 0xff, 0xfc, 0xf4, 0xeb, 0xef, 0x01, 0x02, 0x14, 0xfb,
#   0xf2, 0x0b, 0xef, 0xfe, 0x07, 0x00, 0x03, 0x01, 0xf9, 0xfd, 0x20, 0xed,
#   0x08, 0x0f, 0xf7, 0xef, 0x1a, 0xf7, 0x00, 0x04, 0x02, 0xfc, 0xf8, 0x09,
#   0x04, 0xeb, 0x07, 0xef, 0xff, 0xeb, 0xff, 0xfc, 0x09, 0xec, 0x11, 0xc7,
#   0xfe, 0xf3, 0x12, 0xd0, 0xfd, 0xf8, 0xf0, 0xdb, 0xf6, 0x02, 0x00, 0xe8,
#   0x07, 0xf2, 0xfa, 0xe1, 0xf2, 0x0a, 0x00, 0xe1, 0xe6, 0x08, 0xfe, 0xf7,
#   0x07, 0xfc, 0x0f, 0xfb, 0x0c, 0xed, 0x0c, 0xf2, 0x1a, 0x0a, 0x03, 0xe9,
#   0xe2, 0xee, 0x01, 0xfe, 0xfc, 0xf4, 0x08, 0xf0, 0x24, 0x12, 0x00, 0xd9,
#   0xef, 0x06, 0x0c, 0xf2, 0x11, 0xfb, 0x0b, 0x02, 0xfe, 0xfb, 0xf7, 0xfd,
#   0x06, 0xf7, 0x0e, 0xea, 0xe6, 0xf7, 0xf9, 0xe3, 0x10, 0xfa, 0x22, 0x11,
#   0xd6, 0xf7, 0xe8, 0xde, 0xdb, 0xf1, 0xee, 0x00, 0x0a, 0xe4, 0x1b, 0xf8,
#   0xec, 0x08, 0xec, 0xff, 0x11, 0xf3, 0xf1, 0xde, 0x04, 0x09, 0xf3, 0xbc,
#   0xef, 0x0d, 0xdf, 0xda, 0x0b, 0xd3, 0xdc, 0xf5, 0xed, 0xfe, 0xfc, 0xfc,
#   0xf6, 0xe4, 0xe1, 0xe6, 0x12, 0xf7, 0x02, 0x0e, 0xee, 0x08, 0xe8, 0xfb,
#   0x14, 0xec, 0xf5, 0xe6, 0x02, 0xe5, 0xeb, 0xf1, 0x05, 0xff, 0xf4, 0xdd,
#   0x00, 0xea, 0x14, 0xf4, 0xec, 0x12, 0xfa, 0xfa, 0xfd, 0x0d, 0xf7, 0x07,
#   0x00, 0x08, 0x03, 0x0f, 0xf4, 0x0b, 0x07, 0x0b, 0xf7, 0xfd, 0xf6, 0xe0,
#   0xfd, 0xfc, 0xed, 0xfa, 0xff, 0x0f, 0xf5, 0x0e, 0xf1, 0xdd, 0x15, 0xf8,
#   0xf3, 0x01, 0x05, 0xec, 0xee, 0xec, 0xff, 0xd1, 0xfa, 0xf4, 0x04, 0xf2,
#   0xed, 0xfd, 0xe3, 0xe4, 0x05, 0x0f, 0xe0, 0x0d, 0xfe, 0x17, 0x04, 0xf4,
#   0xe9, 0xff, 0x1a, 0x13, 0xff, 0x0d, 0xe5, 0x0b, 0x0a, 0xf9, 0x05, 0xed,
#   0x00, 0xfe, 0xfc, 0x0b, 0xf1, 0xeb, 0x0a, 0x07, 0xdc, 0x1d, 0xec, 0xf3,
#   0xfe, 0xfc, 0x0d, 0xfb, 0x00, 0x04, 0x1a, 0x08, 0xf1, 0x00, 0xff, 0x09,
#   0xe6, 0xf2, 0xf5, 0xeb, 0xd3, 0xfb, 0xf4, 0x16, 0x03, 0x02, 0xeb, 0x02,
#   0xc5, 0xfc, 0x0e, 0x13, 0xfe, 0xed, 0xdc, 0x08, 0xfa, 0x0d, 0xf8, 0xda,
#   0x0f, 0x18, 0xfb, 0x03, 0x26, 0xf7, 0x09, 0x13, 0xfe, 0xfa, 0xfa, 0xf2,
#   0xed, 0xf5, 0x02, 0x15, 0xdf, 0xf3, 0xe8, 0xf3, 0x07, 0xe2, 0xfd, 0x0a,
#   0x08, 0xe7, 0x01, 0xf8, 0xe3, 0x00, 0x07, 0x05, 0x1b, 0xed, 0xf7, 0xf6,
#   0x08, 0xff, 0xe5, 0x0e, 0xf1, 0xba, 0xec, 0xd5, 0xef, 0xfd, 0x0b, 0xee,
#   0x02, 0xe8, 0xee, 0xfc, 0xe7, 0xe8, 0x0d, 0xef, 0x0c, 0xf6, 0xf6, 0x1a,
#   0x04, 0xfc, 0x0d, 0xe8, 0xff, 0xf2, 0x12, 0x09, 0x02, 0x01, 0xfe, 0xff,
#   0xf9, 0xe1, 0x21, 0xe0, 0xff, 0xfe, 0x15, 0xf1, 0x11, 0xde, 0xfc, 0xfb,
#   0xf0, 0xf3, 0x00, 0x08, 0x05, 0xf0, 0x04, 0x09, 0x02, 0xee, 0x13, 0xf1,
#   0xee, 0xe6, 0x17, 0xf3, 0x13, 0xf2, 0x02, 0xe0, 0x0b, 0xdf, 0xf2, 0xf1,
#   0x16, 0xff, 0x0a, 0xfb, 0xf7, 0x07, 0xfd, 0x00, 0xf2, 0xec, 0xf5, 0xfe,
#   0xfc, 0xf8, 0x13, 0x00, 0x06, 0xff, 0xfc, 0xee, 0x02, 0xe0, 0x02, 0xf5,
#   0xf8, 0xf3, 0xf5, 0xf8, 0xec, 0xff, 0xe6, 0xd9, 0x09, 0xfd, 0xd9, 0xef,
#   0x01, 0xf9, 0xf3, 0xf8, 0xfd, 0x01, 0x02, 0xfe, 0xf9, 0xed, 0x01, 0xd3,
#   0x02, 0xff, 0xed, 0xed, 0xef, 0xe3, 0xf5, 0xeb, 0x04, 0xfe, 0xea, 0xf9,
#   0xf7, 0xf2, 0xea, 0x09, 0x0e, 0x04, 0xf8, 0xee, 0xf0, 0xed, 0xe3, 0xdf,
#   0xec, 0x0a, 0xfd, 0xe9, 0xe3, 0xed, 0xed, 0x01, 0x08, 0x03, 0xb5, 0xfa,
#   0xf3, 0xf4, 0xf0, 0x0b, 0xff, 0x12, 0xf9, 0xeb, 0xf7, 0xf2, 0x0c, 0xde,
#   0x07, 0xf9, 0xfb, 0xeb, 0xf3, 0xfc, 0x10, 0x11, 0xe6, 0xff, 0xfa, 0xf1,
#   0x16, 0xeb, 0x07, 0xf7, 0x05, 0x11, 0xda, 0xf9, 0x08, 0xfb, 0xfb, 0x03,
#   0x0d, 0x0f, 0x10, 0x09, 0xeb, 0x0b, 0x04, 0xfa, 0xe9, 0x0a, 0xf4, 0xde,
#   0xf6, 0x18, 0xf6, 0xcd, 0xf5, 0xdb, 0xfd, 0xd8, 0xf6, 0xfb, 0x03, 0x12,
#   0xe6, 0xe1, 0xfb, 0xee, 0x0e, 0xf9, 0xfb, 0xfc, 0xf9, 0xee, 0xe8, 0x0d,
#   0xfc, 0x0c, 0xd8, 0x01, 0x0c, 0xfc, 0xdd, 0x0a, 0x0d, 0x03, 0x02, 0xed,
#   0xed, 0xe0, 0x04, 0xf1, 0xef, 0xf6, 0xf8, 0xf3, 0xdb, 0xea, 0x0e, 0xdd,
#   0xfd, 0x02, 0x0d, 0xfb, 0x11, 0xe5, 0xf0, 0xe3, 0xe9, 0xfb, 0x09, 0xea,
#   0xe8, 0x0d, 0x1d, 0x11, 0xf4, 0xee, 0x09, 0x1f, 0xf9, 0xfc, 0x03, 0xf9,
#   0xea, 0xfb, 0xf6, 0x15, 0x2a, 0x07, 0xf2, 0xf3, 0xf1, 0x10, 0xec, 0xf2,
#   0x18, 0x11, 0xf9, 0x04, 0x08, 0xf0, 0xfe, 0x1d, 0xf0, 0x0d, 0xec, 0xeb,
#   0x05, 0xe5, 0xef, 0x17, 0x0a, 0x08, 0x00, 0xfe, 0xf0, 0xeb, 0xf7, 0xe1,
#   0x17, 0x06, 0xfb, 0xf8, 0x05, 0xf5, 0x08, 0xfc, 0x09, 0x05, 0xee, 0xf1,
#   0xf4, 0xf4, 0x0e, 0xfb, 0xdd, 0x09, 0xf3, 0xf1, 0xff, 0x07, 0xf5, 0xf8,
#   0xf9, 0xe1, 0xf9, 0x14, 0xf0, 0xed, 0x19, 0x08, 0x05, 0x07, 0x00, 0xf9,
#   0x16, 0xf8, 0xf2, 0xfc, 0x0f, 0x05, 0xed, 0xf4, 0x03, 0x04, 0x0c, 0xe6,
#   0x00, 0x11, 0x05, 0x03, 0xe4, 0xf9, 0x12, 0x03, 0xf2, 0x0f, 0x08, 0xdc,
#   0xef, 0xff, 0x0d, 0xe0, 0xe5, 0xe5, 0xed, 0x0c, 0x0d, 0xfe, 0x1b, 0x09,
#   0x04, 0xf7, 0xf5, 0xee, 0xf5, 0xf3, 0x17, 0xe2, 0xf6, 0xfc, 0x0d, 0x17,
#   0xf8, 0xf1, 0xf4, 0xf2, 0xfc, 0xf2, 0x0a, 0xf4, 0xf8, 0xe9, 0xfe, 0xe9,
#   0x06, 0xdf, 0xe9, 0x04, 0xfe, 0xfe, 0xfd, 0xff, 0xf3, 0x04, 0xfb, 0xf1,
#   0xfc, 0x0c, 0xdd, 0xe4, 0xe2, 0x02, 0x22, 0x17, 0xdc, 0xe9, 0x01, 0x08,
#   0x1c, 0xf5, 0xdc, 0xf8, 0x01, 0xfd, 0x0f, 0xf6, 0x11, 0xf3, 0xf5, 0x01,
#   0x10, 0x0c, 0xf7, 0x0e, 0x16, 0x10, 0xfc, 0xf9, 0xe6, 0x03, 0xea, 0x00,
#   0x1e, 0x0e, 0x02, 0xfb, 0x03, 0x06, 0xfc, 0x0a, 0x10, 0x12, 0x0f, 0xea,
#   0xe9, 0xff, 0x06, 0x06, 0xf1, 0x00, 0xfd, 0xf1, 0x12, 0xf7, 0x0a, 0x0b,
#   0xfa, 0x06, 0xf8, 0xd8, 0x03, 0xd2, 0xd8, 0xec, 0xdf, 0xe7, 0x0d, 0xcf,
#   0xf6, 0xf7, 0xe2, 0xf3, 0xe8, 0xf1, 0xf8, 0xf5, 0xec, 0xfb, 0xf6, 0x03,
#   0x11, 0x05, 0x19, 0xf1, 0xee, 0xf3, 0x07, 0xe6, 0x12, 0x21, 0x1a, 0x03,
#   0xea, 0xeb, 0x0e, 0xe2, 0x06, 0x0a, 0xdb, 0xfd, 0x00, 0x0a, 0xf9, 0xfa,
#   0xfd, 0x03, 0xe9, 0xfd, 0xf6, 0xff, 0xea, 0xef, 0xf4, 0xf5, 0xfb, 0xff,
#   0x0a, 0xed, 0xf2, 0xda, 0xf6, 0xee, 0xd6, 0xed, 0x12, 0xf0, 0xfd, 0x03,
#   0xf2, 0xf8, 0xc6, 0xf5, 0xfa, 0xf4, 0xfd, 0xe9, 0x15, 0x06, 0x07, 0x0f,
#   0xf7, 0xf3, 0x04, 0xf6, 0x15, 0xf5, 0x06, 0xf5, 0xf9, 0xd8, 0x18, 0xe2,
#   0x02, 0xfd, 0xfc, 0xeb, 0xed, 0xf3, 0xe3, 0x0d, 0x28, 0xf8, 0xee, 0xfb,
#   0xfa, 0x03, 0x0a, 0xe4, 0xf6, 0xfb, 0x08, 0xe5, 0xe6, 0x06, 0xf5, 0x15,
#   0x0c, 0x18, 0x14, 0xe5, 0x1a, 0xf7, 0xf3, 0x03, 0x26, 0x0f, 0xef, 0xf5,
#   0xea, 0xe8, 0x0d, 0xe9, 0x07, 0x21, 0xf5, 0x00, 0x0e, 0xfc, 0xf5, 0x01,
#   0x06, 0x03, 0x01, 0x09, 0xfa, 0xf4, 0x06, 0xfc, 0xf4, 0x04, 0xea, 0x02,
#   0x1f, 0x0e, 0xfb, 0xf6, 0x06, 0x0b, 0xe8, 0x07, 0xf7, 0xeb, 0x16, 0xf0,
#   0xe7, 0xf4, 0xf0, 0xf5, 0x02, 0xe4, 0x09, 0x08, 0xec, 0x08, 0x00, 0xf7,
#   0xf2, 0xfb, 0xfe, 0xea, 0x2c, 0x1b, 0xf8, 0xeb, 0xd8, 0xf6, 0xed, 0xf7,
#   0x05, 0x1d, 0x05, 0xf4, 0xe6, 0x05, 0x06, 0xf8, 0xfa, 0x07, 0xff, 0xe4,
#   0xf3, 0x09, 0x02, 0xef, 0xf3, 0x06, 0xf8, 0xe1, 0xe7, 0xe7, 0x0f, 0xf8,
#   0xf0, 0xe9, 0xfd, 0xdc, 0xf6, 0xe8, 0x0f, 0xe7, 0x04, 0xe9, 0xf8, 0x04,
#   0xee, 0xe7, 0x04, 0xfb, 0xf8, 0xf1, 0xe6, 0xe6, 0x06, 0xfb, 0xfd, 0xe9,
#   0x16, 0xef, 0xe9, 0x00, 0xea, 0xfc, 0x03, 0xe2, 0x0f, 0xdd, 0xf1, 0xe3,
#   0xfc, 0xff, 0x03, 0xfe, 0xf4, 0xfa, 0x10, 0xe8, 0xe2, 0x07, 0xfa, 0xeb,
#   0xe6, 0x02, 0xfa, 0x08, 0xf5, 0xff, 0x06, 0xe7, 0xfb, 0xfa, 0xea, 0xf4,
#   0xef, 0xed, 0xdf, 0x0f, 0x09, 0x07, 0x07, 0x00, 0xf5, 0xf2, 0xf8, 0x10,
#   0x26, 0x19, 0x01, 0x01, 0x01, 0xe9, 0x0a, 0xff, 0x1f, 0x05, 0x0e, 0xf7,
#   0x0b, 0x12, 0x0b, 0x1a, 0x15, 0x0d, 0x01, 0xfb, 0x0a, 0xe2, 0x07, 0xd9,
#   0x06, 0xf5, 0x0c, 0x0a, 0xfd, 0xfb, 0x0d, 0xf7, 0xf5, 0xfd, 0x07, 0x0d,
#   0xec, 0x0e, 0x04, 0x08, 0x0c, 0xe7, 0xfd, 0xe3, 0xf1, 0xf6, 0x02, 0x04,
#   0xf4, 0xfc, 0x03, 0xee, 0xfd, 0x00, 0xec, 0xfc, 0x0f, 0x21, 0xf6, 0xed,
#   0xef, 0xe4, 0x09, 0xf6, 0x1d, 0x0e, 0x00, 0x01, 0xf2, 0x12, 0xfc, 0xe8,
#   0x18, 0x0d, 0xe8, 0xfa, 0xf3, 0xf3, 0x0c, 0xed, 0xfa, 0x0a, 0xf6, 0xf8,
#   0xf3, 0xf3, 0xf0, 0xe9, 0xdc, 0xfa, 0x0a, 0xd3, 0x01, 0xe5, 0x02, 0xe0,
#   0xf6, 0xff, 0xe8, 0x01, 0x11, 0xe8, 0x03, 0xd8, 0xea, 0xf9, 0xeb, 0xee,
#   0x06, 0xef, 0x05, 0xdd, 0x04, 0xfe, 0x0e, 0x1a, 0x15, 0xf7, 0x13, 0xf1,
#   0x01, 0xf4, 0xf1, 0xf9, 0x06, 0xed, 0xfe, 0xf6, 0xea, 0xf9, 0xf9, 0x08,
#   0xfb, 0xf6, 0x00, 0xf0, 0x1e, 0xfb, 0xf9, 0xf4, 0xf3, 0x06, 0x0f, 0x12,
#   0x0b, 0x0c, 0x0a, 0x05, 0xee, 0xef, 0xfe, 0xfd, 0x10, 0x13, 0xe2, 0x34,
# ...
#   0xff, 0x02, 0xf0, 0xc1, 0x18, 0x08, 0xeb, 0xf8, 0xf8, 0xfc, 0xf2, 0xfd,
#   0xe8, 0xe4, 0xe9, 0x00, 0xf5, 0xf8, 0x17, 0x02, 0xff, 0xee, 0xf2, 0xfa,
#   0xe7, 0x0a, 0x03, 0xf2, 0xf3, 0x04, 0x12, 0xef, 0x07, 0xf9, 0x01, 0xd9,
#   0xdd, 0xfc, 0xf2, 0xf0, 0xf8, 0xeb, 0xf1, 0xfb, 0xe2, 0xfa, 0xfe, 0x18,
#   0x06, 0x03, 0x08, 0xc6, 0xf6, 0x0a, 0xfc, 0x0c, 0x06, 0xf3, 0x03, 0xf2,
#   0xfa, 0x0d, 0x0b, 0x09, 0xf4, 0xf0, 0x12, 0xfc, 0xea, 0xee, 0x0e, 0x06,
#   0x04, 0x0d, 0xfe, 0xd7, 0xdf, 0xf1, 0xed, 0xec, 0xf4, 0x06, 0xf2, 0xe5,
#   0xef, 0xf3, 0xff, 0xe3, 0x03, 0x00, 0xe8, 0x00, 0x28, 0x17, 0xeb, 0xf4,
#   0x07, 0xf8, 0x00, 0xfb, 0xf9, 0xf7, 0xfd, 0xec, 0x06, 0xf8, 0xec, 0x14,
#   0x03, 0xe9, 0xfb, 0xf0, 0xea, 0xf1, 0xfe, 0x1d, 0x17, 0x14, 0xf4, 0xff,
#   0x0c, 0xfc, 0xfa, 0x05, 0xfb, 0x13, 0x12, 0x11, 0x02, 0x1d, 0xf3, 0xf6,
#   0xff, 0x04, 0xfc, 0xf6, 0x0d, 0xea, 0x05, 0x27, 0x1a, 0x15, 0xfa, 0xf6,
#   0x15, 0xed, 0xff, 0x0e, 0x14, 0x25, 0x06, 0x0d, 0x0f, 0xe6, 0xe9, 0xe9,
#   0x03, 0x1d, 0xe9, 0xf7, 0x02, 0xe5, 0xd3, 0xdc, 0xf7, 0x09, 0x01, 0x19,
#   0x04, 0xfc, 0xf2, 0x01, 0xd6, 0x03, 0xfd, 0xee, 0xe9, 0xe3, 0x02, 0xff,
#   0xec, 0x0d, 0xe5, 0xf2, 0x07, 0xed, 0xf8, 0xe2, 0x15, 0x09, 0xfc, 0x00,
#   0x09, 0xe3, 0x02, 0xd5, 0xf0, 0x04, 0x0e, 0xf7, 0xfe, 0xfc, 0xe4, 0x05,
#   0xd2, 0x02, 0x01, 0x21, 0x09, 0xee, 0xe9, 0xf2, 0xff, 0x02, 0xfd, 0xdf,
#   0x1b, 0x01, 0xed, 0xcd, 0xf2, 0xfc, 0xf5, 0x02, 0xe2, 0xf4, 0x0d, 0xe1,
#   0x01, 0xe8, 0x0f, 0xfa, 0x00, 0x0e, 0x0d, 0xe8, 0xee, 0xeb, 0x04, 0xfb,
#   0xe5, 0x08, 0xff, 0xea, 0xe8, 0xf6, 0x09, 0xf3, 0xfa, 0xed, 0x16, 0xf4,
#   0x10, 0x17, 0xf3, 0xfe, 0x02, 0xf0, 0xe9, 0xf8, 0xea, 0x07, 0x09, 0xff,
#   0x0b, 0xf2, 0xf1, 0xf8, 0xf6, 0x07, 0xe7, 0x07, 0x04, 0xf7, 0x10, 0x18,
#   0x06, 0x19, 0xf0, 0xef, 0xf5, 0xe8, 0xfe, 0xd7, 0x0e, 0x15, 0x0c, 0xff,
#   0xf8, 0x03, 0xef, 0xf8, 0xe7, 0x16, 0xfd, 0x11, 0x0a, 0x0c, 0x05, 0x05,
#   0x1d, 0x17, 0xfc, 0xec, 0xfe, 0xdf, 0x00, 0x10, 0x0f, 0x1d, 0x00, 0xf9,
#   0x04, 0xe6, 0xe3, 0xea, 0x14, 0x1a, 0xef, 0x17, 0x07, 0x00, 0xf2, 0xed,
#   0xf5, 0x17, 0xf2, 0xe7, 0xf9, 0xfe, 0xe4, 0xd7, 0xf8, 0x03, 0xdb, 0xf0,
#   0xf3, 0xfd, 0x19, 0xf0, 0xfb, 0xe9, 0xf1, 0x00, 0xed, 0xf4, 0xfd, 0xd7,
#   0x10, 0x04, 0xfb, 0xfc, 0xf9, 0xec, 0x01, 0xf0, 0x04, 0xf2, 0xe9, 0xef,
#   0x01, 0x03, 0xef, 0xe5, 0xf0, 0xef, 0xfc, 0xfa, 0x0b, 0xe2, 0xf2, 0xde,
#   0xfd, 0x06, 0xeb, 0xfd, 0xfe, 0x02, 0x0b, 0xee, 0x08, 0xf9, 0x08, 0x02,
#   0xfa, 0x08, 0x10, 0xf3, 0xf9, 0xf0, 0x09, 0xee, 0xfa, 0xfb, 0xfd, 0xe3,
#   0xd9, 0xf5, 0x03, 0xfb, 0xed, 0xff, 0xfb, 0xf2, 0xfd, 0xf6, 0xf2, 0xf1,
#   0xf8, 0xe9, 0xfa, 0xfe, 0x00, 0x1b, 0xf8, 0xfc, 0x14, 0xf6, 0xf8, 0xfa,
#   0x08, 0x09, 0x02, 0xf4, 0x03, 0xf3, 0x00, 0x10, 0xe9, 0xfa, 0x18, 0x13,
#   0xff, 0xf6, 0xf7, 0x17, 0xfd, 0x19, 0xfa, 0x12, 0x0d, 0x00, 0xe0, 0x12,
#   0xf6, 0x21, 0x08, 0xf7, 0x0b, 0xfa, 0xf2, 0x03, 0xe9, 0xfe, 0x01, 0x01,
#   0x0e, 0x0a, 0x03, 0x10, 0x0c, 0x14, 0xf1, 0xf1, 0x0d, 0xce, 0xe7, 0x24,
#   0x0d, 0x15, 0xec, 0xfa, 0x0e, 0xf3, 0xf5, 0xe8, 0x01, 0x1a, 0xf8, 0x08,
#   0xf9, 0xfa, 0xee, 0xfb, 0xfb, 0x23, 0x0a, 0x0f, 0xfb, 0xdb, 0xf3, 0xf9,
#   0xf7, 0xfb, 0xef, 0x05, 0xf1, 0xf2, 0x02, 0xfb, 0xec, 0xff, 0x0b, 0xf1,
#   0xee, 0xe3, 0x0a, 0xe8, 0x02, 0x10, 0x09, 0x0d, 0xfb, 0x05, 0xfc, 0xf7,
#   0xec, 0x04, 0xf8, 0xf3, 0x06, 0xfe, 0xf3, 0xf4, 0xef, 0xfd, 0xe9, 0xf5,
#   0x03, 0xf3, 0xe9, 0xe9, 0x06, 0x11, 0xfb, 0x02, 0xf4, 0x1b, 0xe4, 0xf1,
#   0xf7, 0x03, 0xde, 0x13, 0xec, 0x04, 0xf4, 0xf7, 0x11, 0xe1, 0xfa, 0xee,
#   0xfb, 0xfe, 0x0f, 0xd2, 0xe7, 0xed, 0xed, 0x05, 0xf1, 0xf0, 0xfc, 0xfa,
#   0xe8, 0xf0, 0x07, 0xf4, 0xf2, 0xfa, 0xff, 0x01, 0xff, 0x03, 0xf6, 0xfe,
#   0xfd, 0x01, 0xf6, 0x02, 0x05, 0x05, 0xfe, 0xfe, 0xfb, 0xeb, 0xf7, 0x25,
#   0xf8, 0xf5, 0x00, 0x09, 0xfc, 0xff, 0xff, 0x25, 0x04, 0xfe, 0xf4, 0xf6,
#   0x09, 0x00, 0xeb, 0x03, 0x1b, 0x05, 0xff, 0x07, 0xfd, 0x04, 0xf2, 0x15,
#   0xe7, 0x1a, 0x01, 0x12, 0x06, 0xe6, 0x03, 0x09, 0x27, 0x1c, 0xf2, 0xf1,
#   0x02, 0xf5, 0xe4, 0xff, 0x1c, 0x18, 0x05, 0x18, 0x04, 0x00, 0xe7, 0xfa,
#   0x00, 0x23, 0xf8, 0x05, 0x04, 0x04, 0xde, 0xdf, 0x04, 0x07, 0xe7, 0x02,
#   0x08, 0xfd, 0x05, 0x02, 0x07, 0x02, 0xf0, 0x05, 0xf2, 0x05, 0xfd, 0xf5,
#   0x0b, 0xf1, 0x17, 0x0f, 0xf8, 0x02, 0x02, 0xf0, 0x0c, 0x07, 0xf2, 0x03,
#   0x03, 0xf9, 0xf9, 0xee, 0xeb, 0x04, 0x09, 0x06, 0x12, 0xf7, 0xf5, 0xef,
#   0xd8, 0x02, 0xf0, 0xfe, 0x04, 0xf2, 0x00, 0xdc, 0xe7, 0x02, 0xeb, 0x08,
#   0x09, 0x03, 0xf8, 0xe1, 0xff, 0xfe, 0x0a, 0xf2, 0x01, 0xf0, 0x07, 0x08,
#   0xee, 0xe5, 0x05, 0x0f, 0x0a, 0xf3, 0x0d, 0xe4, 0x00, 0xf6, 0xe8, 0xfc,
#   0xe9, 0x00, 0xf9, 0xe8, 0xea, 0xf8, 0x09, 0xfe, 0xfc, 0xff, 0xf6, 0xfa,
#   0xe0, 0x0d, 0x03, 0xf3, 0xfb, 0xf6, 0x0d, 0x00, 0xff, 0x01, 0x03, 0xf8,
#   0x1b, 0x04, 0x1a, 0x1f, 0xf1, 0x07, 0xfa, 0x09, 0x0e, 0xfe, 0xf1, 0x21,
#   0x01, 0xfe, 0x0b, 0xf6, 0x00, 0x05, 0xe6, 0xf9, 0xfc, 0x06, 0x0e, 0x00,
#   0x16, 0xfd, 0xfb, 0x01, 0x03, 0x0b, 0xf4, 0xf4, 0xff, 0xf5, 0xff, 0x09,
#   0xfc, 0x23, 0x08, 0xf8, 0x02, 0xe9, 0xef, 0x0b, 0x29, 0x17, 0x02, 0xe7,
#   0x17, 0xed, 0xda, 0xfb, 0x16, 0x10, 0xef, 0xfc, 0x0e, 0x00, 0xe0, 0xee,
#   0x06, 0xff, 0xf7, 0x0d, 0xfe, 0x04, 0xeb, 0xee, 0x00, 0xf8, 0x03, 0x0b,
#   0x0e, 0x0d, 0x04, 0xfd, 0xf8, 0x05, 0x10, 0xfb, 0xf3, 0xef, 0xf6, 0xf2,
#   0xe9, 0x07, 0x07, 0xf9, 0xf3, 0xf3, 0xf6, 0xdf, 0xfb, 0x18, 0xf0, 0x09,
#   0x05, 0xee, 0xe4, 0xe7, 0xf3, 0xfb, 0xea, 0x10, 0xf9, 0x02, 0xe5, 0xf8,
#   0xdb, 0xfc, 0x04, 0x00, 0xfe, 0x09, 0xfb, 0xd9, 0xec, 0x07, 0x15, 0x0e,
#   0x06, 0xf3, 0xf6, 0xe3, 0xe8, 0xf9, 0xee, 0x0d, 0xfe, 0x04, 0x13, 0xf4,
#   0x04, 0xf3, 0xfc, 0xf3, 0xea, 0x05, 0x02, 0xdf, 0xe6, 0xeb, 0xfe, 0xff,
#   0x0b, 0xed, 0x00, 0x03, 0x02, 0x16, 0x04, 0xf5, 0x04, 0xe5, 0xfc, 0x08,
#   0x0a, 0xf8, 0x03, 0xf3, 0x10, 0xea, 0xf4, 0x06, 0x10, 0xef, 0x12, 0xf5,
#   0x09, 0xf5, 0x00, 0x0d, 0x0e, 0x0b, 0x05, 0x09, 0xf7, 0xe5, 0x00, 0xfc,
#   0x01, 0x07, 0xe9, 0xf7, 0x18, 0xf6, 0xf6, 0x0d, 0x0a, 0x08, 0xf2, 0xf0,
#   0xff, 0xf6, 0xf6, 0x1b, 0x1f, 0x07, 0x02, 0x01, 0x05, 0xfd, 0xef, 0x19,
#   0x03, 0x09, 0xf7, 0xfd, 0xf1, 0x01, 0xf7, 0xe7, 0xf9, 0xf7, 0xeb, 0x01,
#   0x01, 0x10, 0xec, 0xd7, 0xfc, 0xfe, 0xf2, 0xfb, 0x09, 0x01, 0xf8, 0x0f,
#   0x13, 0xee, 0xf4, 0xfe, 0xfd, 0x04, 0x0c, 0xfc, 0x00, 0x08, 0x1d, 0xfb,
#   0xee, 0x02, 0xf7, 0xe3, 0x0d, 0x01, 0x07, 0xf4, 0xf2, 0xfb, 0x05, 0x03,
#   0xe9, 0xfd, 0xfc, 0x02, 0xf9, 0xff, 0xf2, 0xfb, 0xd1, 0x03, 0xed, 0xf4,
#   0x07, 0x04, 0xef, 0x0b, 0xfe, 0xf6, 0xd1, 0xf9, 0xe3, 0x0a, 0x04, 0xf4,
#   0x08, 0xf3, 0x08, 0xf5, 0xfd, 0x10, 0xfe, 0xef, 0xdd, 0xf6, 0x0f, 0x01,
#   0x01, 0x10, 0x00, 0x05, 0xf6, 0xf7, 0x00, 0xfd, 0xec, 0x05, 0x02, 0xef,
#   0xfe, 0xf5, 0x0e, 0x11, 0xfe, 0xfa, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09,
#   0x10, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xa0, 0x0f, 0x00, 0x00, 0x16, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65,
#   0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f,
#   0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x7c, 0xfa, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x84, 0x6e, 0x1a, 0x3b, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x82, 0xfb, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x0f, 0xff, 0xff, 0xff, 0x9a, 0xfd, 0xff, 0xff,
#   0x18, 0xff, 0xff, 0xff, 0x37, 0xfd, 0xff, 0xff, 0xe9, 0xfc, 0xff, 0xff,
#   0x30, 0x01, 0x00, 0x00, 0x5e, 0xfe, 0xff, 0xff, 0xea, 0xfd, 0xff, 0xff,
#   0x8a, 0xfb, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02, 0x10, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x00,
#   0xf8, 0xfa, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0xbd, 0xae, 0x9d, 0x38, 0x28, 0x1c, 0xb0, 0x38,
#   0x09, 0xe7, 0xa7, 0x38, 0x81, 0xf8, 0xad, 0x38, 0x26, 0x78, 0xa9, 0x38,
#   0xba, 0x93, 0xc2, 0x38, 0xda, 0xfd, 0xb3, 0x38, 0x4d, 0xdb, 0xb0, 0x38,
#   0x08, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x52, 0xfc, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x80, 0x02, 0x00, 0x00, 0xd2, 0x9a, 0x33, 0xb0,
#   0x4e, 0xb1, 0xa7, 0xba, 0x48, 0x01, 0x05, 0xb3, 0xb9, 0xa8, 0x1a, 0x87,
#   0x41, 0xe1, 0x67, 0xe4, 0xba, 0x5b, 0x98, 0x1e, 0x47, 0x1c, 0xc7, 0x18,
#   0xb7, 0xe2, 0x85, 0x26, 0xe3, 0xd9, 0x0d, 0x1e, 0xe0, 0x8c, 0xb9, 0xe0,
#   0x89, 0x2c, 0xab, 0xa7, 0x0e, 0x51, 0xe8, 0x53, 0x7b, 0xe3, 0xb4, 0xcd,
#   0xe5, 0x67, 0x2f, 0xc2, 0x17, 0xab, 0x79, 0x4c, 0xaf, 0xc5, 0x81, 0xc6,
#   0x45, 0x97, 0xea, 0xa5, 0x8e, 0xfa, 0x2f, 0x2d, 0xcb, 0x82, 0xd6, 0x42,
#   0xa6, 0x05, 0x5d, 0x2f, 0x2d, 0xe3, 0xdf, 0xed, 0x1c, 0xac, 0x21, 0xd9,
#   0xdb, 0xb2, 0xf3, 0xb5, 0x28, 0xaa, 0xe0, 0xa8, 0x06, 0x08, 0x17, 0x4d,
#   0xd8, 0x35, 0x3e, 0x37, 0x2d, 0xc0, 0xfb, 0x90, 0xcb, 0x26, 0xfd, 0xb5,
#   0x2b, 0xc9, 0x32, 0x22, 0x4c, 0xcc, 0x4c, 0x23, 0xfd, 0x2b, 0x96, 0x9d,
#   0xa4, 0x2a, 0x08, 0xa7, 0x98, 0x84, 0xb6, 0xca, 0xcb, 0x1f, 0xcd, 0xdb,
#   0x20, 0xad, 0x81, 0x94, 0x0a, 0x20, 0x01, 0xb4, 0x27, 0xef, 0xbb, 0x0b,
#   0xf7, 0xfd, 0x32, 0x1c, 0xb0, 0x86, 0x2f, 0x31, 0xf3, 0xfe, 0x15, 0xb8,
#   0x00, 0xd5, 0x3b, 0xa0, 0xfa, 0x42, 0xaf, 0xd7, 0x16, 0xe7, 0xe2, 0x3f,
#   0x27, 0xce, 0x96, 0x93, 0x45, 0xc6, 0x98, 0x3a, 0xb3, 0xba, 0xcd, 0x01,
#   0x57, 0x42, 0x28, 0xba, 0x8d, 0xa8, 0x43, 0x09, 0x4f, 0xda, 0x8d, 0x3a,
#   0x81, 0x2f, 0x06, 0x46, 0x58, 0x41, 0x6a, 0x20, 0xea, 0x9e, 0xa9, 0xa8,
#   0xe6, 0x2d, 0x0e, 0xfb, 0x2e, 0xf4, 0xb9, 0xdc, 0x9b, 0x89, 0xbe, 0xe7,
#   0xe7, 0xb0, 0x51, 0xc1, 0x23, 0x51, 0xae, 0x41, 0xaa, 0xf1, 0x97, 0xf3,
#   0xee, 0x60, 0xa5, 0xe3, 0x34, 0xa4, 0x1c, 0x41, 0xb9, 0x62, 0x11, 0x1e,
#   0x1c, 0xdd, 0x0f, 0x9f, 0xb6, 0x4e, 0x00, 0x00, 0xa4, 0x2b, 0x52, 0xf3,
#   0x09, 0xe8, 0x20, 0xab, 0x0d, 0xa7, 0x58, 0xdc, 0x35, 0x3a, 0xad, 0x03,
#   0x93, 0xa8, 0xad, 0x1c, 0x4e, 0x13, 0xbe, 0xbc, 0x81, 0xaf, 0xbe, 0xa9,
#   0xb8, 0xd9, 0xa4, 0x15, 0xc7, 0xee, 0xa6, 0x59, 0xb7, 0x2e, 0x10, 0x37,
#   0xba, 0x0b, 0x9f, 0xc1, 0xea, 0x06, 0xab, 0x1d, 0x16, 0xba, 0x96, 0x18,
#   0x4c, 0x36, 0x22, 0x9c, 0xab, 0x00, 0xe4, 0x11, 0xe2, 0x8d, 0xdd, 0x23,
#   0xfc, 0x34, 0x28, 0xef, 0x0b, 0x65, 0x15, 0x0a, 0x13, 0xa6, 0x9e, 0x9a,
#   0x1b, 0x92, 0xfc, 0x40, 0x4b, 0x8f, 0xd3, 0x10, 0x8e, 0x09, 0xd9, 0x9c,
#   0xda, 0x5b, 0x1e, 0x14, 0x0c, 0x3d, 0xe2, 0xa5, 0x81, 0x3f, 0xae, 0xcf,
#   0xf3, 0x53, 0x20, 0x16, 0x3c, 0xa2, 0x0a, 0xde, 0x28, 0xcd, 0xe3, 0x08,
#   0xf4, 0xff, 0xbc, 0x5b, 0xc1, 0x9f, 0xed, 0xdd, 0xa5, 0xb8, 0x8d, 0xf7,
#   0xc3, 0x8d, 0xca, 0xec, 0xa7, 0x37, 0xf2, 0x91, 0xdb, 0x0c, 0xdd, 0xa6,
#   0x3c, 0xfd, 0xdc, 0xc7, 0x1b, 0xbd, 0x45, 0x34, 0xa7, 0xf6, 0x37, 0x98,
#   0x1f, 0x2f, 0x27, 0x60, 0xe7, 0xbe, 0x02, 0x01, 0xe4, 0xd9, 0x01, 0x13,
#   0x2c, 0x3f, 0xf2, 0xa5, 0x0f, 0xbf, 0xe9, 0xf3, 0x38, 0x15, 0x29, 0xd5,
#   0x01, 0xd4, 0xf0, 0x23, 0xb7, 0xe7, 0x31, 0x53, 0x04, 0x30, 0xa4, 0xfb,
#   0x10, 0x9a, 0x2e, 0xdd, 0xf7, 0x4d, 0xd9, 0xf1, 0xe7, 0xb2, 0xdb, 0xcf,
#   0xf4, 0x9a, 0x1c, 0x31, 0xe6, 0x8f, 0x81, 0xba, 0xf5, 0xce, 0x18, 0xb4,
#   0x02, 0x0c, 0xb1, 0xf1, 0xb0, 0xe3, 0x34, 0xdd, 0xff, 0xbd, 0xa6, 0x95,
#   0x8b, 0x83, 0xea, 0x9e, 0xf1, 0x12, 0xb8, 0x33, 0xfc, 0xee, 0xf1, 0x23,
#   0x98, 0xd8, 0x49, 0x3d, 0x81, 0xee, 0xd8, 0x3b, 0x47, 0x0c, 0xf7, 0x91,
#   0xe4, 0xb7, 0x11, 0x1c, 0x3a, 0xb4, 0xcc, 0xb0, 0x2c, 0xe5, 0x04, 0x9a,
#   0xd1, 0xad, 0xfd, 0xb8, 0xd7, 0x33, 0xe7, 0x3f, 0x18, 0xcc, 0xd2, 0x49,
#   0x44, 0xc9, 0x4f, 0x9b, 0x43, 0x3a, 0xff, 0x1a, 0x36, 0xec, 0xce, 0x58,
#   0xa2, 0xa7, 0x42, 0xbb, 0xf0, 0xb8, 0xbe, 0xea, 0x2f, 0x05, 0x5a, 0xff,
#   0xa8, 0x27, 0xb5, 0x8a, 0xf7, 0x49, 0x86, 0x9f, 0x8d, 0x35, 0x8d, 0x13,
#   0xfc, 0x9b, 0x48, 0xe2, 0xdc, 0x43, 0xf2, 0xb7, 0x45, 0xfc, 0x0a, 0xaa,
#   0xd3, 0x25, 0x42, 0xb1, 0x13, 0xa2, 0x85, 0xd8, 0x08, 0x5a, 0xab, 0xd5,
#   0xfe, 0x48, 0xcc, 0x34, 0x49, 0xee, 0x50, 0x0d, 0x47, 0xa2, 0xf0, 0x13,
#   0x37, 0x21, 0xca, 0x54, 0x96, 0xf3, 0x1e, 0x3b, 0x9c, 0x9d, 0xd7, 0xd1,
#   0xcf, 0x81, 0x3e, 0x95, 0x92, 0x21, 0x34, 0xd1, 0xde, 0x0a, 0xf4, 0x3b,
#   0x45, 0x0c, 0xe5, 0xb9, 0x42, 0xd7, 0x10, 0x87, 0xd5, 0x42, 0xac, 0x02,
#   0x15, 0xbb, 0xfd, 0x84, 0xbd, 0xd6, 0xbf, 0xee, 0x9c, 0xde, 0x27, 0x16,
#   0xba, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x09, 0x10, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f, 0x63, 0x6f, 0x6e, 0x76,
#   0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32, 0x44, 0x2f, 0x43, 0x6f,
#   0x6e, 0x76, 0x32, 0x44, 0x00, 0x00, 0x00, 0x00, 0x48, 0xfe, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x52, 0xc7, 0x41, 0x3a, 0xa0, 0x6c, 0x58, 0x3a, 0x87, 0x56, 0x4e, 0x3a,
#   0x9c, 0xcb, 0x55, 0x3a, 0x76, 0x43, 0x50, 0x3a, 0x69, 0x1e, 0x6f, 0x3a,
#   0xcc, 0x31, 0x5d, 0x3a, 0x87, 0x57, 0x59, 0x3a, 0x08, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0xa6, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0xa0, 0x0f, 0x00, 0x00, 0x96, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x02,
#   0x10, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x15, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f,
#   0x66, 0x6c, 0x61, 0x74, 0x74, 0x65, 0x6e, 0x2f, 0x43, 0x6f, 0x6e, 0x73,
#   0x74, 0x00, 0x00, 0x00, 0x04, 0x00, 0x06, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x04, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0x31, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x08, 0x00, 0x07, 0x00, 0x0c, 0x00,
#   0x10, 0x00, 0x14, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02,
#   0x10, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x34, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x23, 0x00, 0x00, 0x00, 0x6d, 0x6f, 0x64, 0x65, 0x6c, 0x5f, 0x31, 0x2f,
#   0x63, 0x6f, 0x6e, 0x76, 0x32, 0x64, 0x2f, 0x43, 0x6f, 0x6e, 0x76, 0x32,
#   0x44, 0x2f, 0x52, 0x65, 0x73, 0x68, 0x61, 0x70, 0x65, 0x2f, 0x73, 0x68,
#   0x61, 0x70, 0x65, 0x00, 0x68, 0xff, 0xff, 0xff, 0x14, 0x00, 0x1c, 0x00,
#   0x08, 0x00, 0x07, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x18, 0x00, 0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
#   0x4c, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xa8, 0x07, 0x00, 0x00, 0x19, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f, 0x64, 0x65, 0x66, 0x61,
#   0x75, 0x6c, 0x74, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x5f, 0x31, 0x3a,
#   0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0xa8, 0x07, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x50, 0x50, 0xd0, 0x3d,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x04, 0x00, 0x04, 0x00, 0x00, 0x00
# };
# unsigned int model_fromPre_wAugs_tflite_len = 19424;
